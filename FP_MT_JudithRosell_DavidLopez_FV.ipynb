# %% [markdown]
# # Building a MT model with backtranslation

# %%
# First of all, we have downloaded from the OPUS parallel corpora database:

# - the ca-en WikiMatrix parallel corpus –> the ca file will be used as monolingual training set
# - the ca-en OpenSubtitles parallel corpus
# - the ca-es OpenSubtitles parallel corpus

# https://opus.nlpl.eu/OpenSubtitles.php

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Preprocess the text files

# %%
# This is just to check the length of each file

with open('/content/drive/MyDrive/MT2/ca-en/init.train.mono.ca', 'r') as f_in:
  content = f_in.read()
  print(len(content))

with open('/content/drive/MyDrive/MT2/ca-en/init.ca-en.ca', 'r') as f_in_ca:
  content_ca = f_in_ca.read()
  print(len(content_ca))
# Out:
# 170807699
# 15851458

# %%
import re

# Preprocess train.mono.ca
# Open the input file
with open('/content/drive/MyDrive/MT2/ca-en/init.train.mono.ca', 'r') as f_in:
    # Open the output file
    with open('/content/drive/MyDrive/MT2/ca-en/train.mono.ca', 'w') as f_out:
        # Loop over each line in the input file
        for line in f_in:
            # Remove special characters
            line = line.lower()
            line = re.sub('[«»"]', '', line)
            # Check if the line contains "(en anglès)"
            if '(en anglès)' not in line:
                # Write the line to the output file
                f_out.write(line)


# Preprocess parallel corpus
# Open the input file
with open('/content/drive/MyDrive/MT2/ca-en/init.ca-en.ca', 'r') as f_in_ca:
    # Open the output file
    with open('/content/drive/MyDrive/MT2/ca-en/ca-en.ca', 'w') as f_out_ca:
        # Loop over each line in the input file
        for line in f_in_ca:
            # Remove special characters
            line = line.lower()
            line = re.sub('[«»"]', '', line)
            # Write the line to the output file
            f_out_ca.write(line)


# Open the input file
with open('/content/drive/MyDrive/MT2/ca-en/init.ca-en.en', 'r') as f_in_en:
    # Open the output file
    with open('/content/drive/MyDrive/MT2/ca-en/ca-en.en', 'w') as f_out_en:
        # Loop over each line in the input file
        for line in f_in_en:
            # Remove special characters
            line = line.lower()
            line = re.sub('[«»"]', '', line)
            # Write the line to the output file
            f_out_en.write(line)

# %% [markdown]
# ## Split the ca-en OpenSubtitles parallel corpus into train, dev and test sets

# %%
# We need to split the ca-en OpenSubtitles parallel corpus into train, dev and test sets

import os
import random

# Define the path to the files
path_ca = '/content/drive/MyDrive/MT2/ca-en/ca-en.ca'
path_en = '/content/drive/MyDrive/MT2/ca-en/ca-en.en'

# Define the percentages for the train, dev, and test sets
train_percent = 0.7
dev_percent = 0.15
test_percent = 0.15

# Define the output directory
output_dir = '/content/drive/MyDrive/MT2/ca-en'

# Create the output directory if it does not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
# Read the files
with open(path_ca, 'r', encoding='utf-8') as f:
    lines_ca = f.readlines()
with open(path_en, 'r', encoding='utf-8') as f:
    lines_en = f.readlines()

# Compute the sizes of the train, dev, and test sets
size = len(lines_ca)
train_size = int(size * train_percent)
dev_size = int(size * dev_percent)
test_size = size - train_size - dev_size

# Shuffle the lines
random.seed(42)
indices = list(range(size))
random.shuffle(indices)

# Split the lines into train, dev, and test sets
train_indices = indices[:train_size]
dev_indices = indices[train_size:train_size+dev_size]
test_indices = indices[train_size+dev_size:]

train_ca = [lines_ca[i] for i in train_indices]
train_en = [lines_en[i] for i in train_indices]
dev_ca = [lines_ca[i] for i in dev_indices]
dev_en = [lines_en[i] for i in dev_indices]
test_ca = [lines_ca[i] for i in test_indices]
test_en = [lines_en[i] for i in test_indices]

# Write the output files
with open(os.path.join(output_dir, 'train.ca-en.ca'), 'w', encoding='utf-8') as f:
    f.writelines(train_ca)
with open(os.path.join(output_dir, 'train.ca-en.en'), 'w', encoding='utf-8') as f:
    f.writelines(train_en)
with open(os.path.join(output_dir, 'dev.ca-en.ca'), 'w', encoding='utf-8') as f:
    f.writelines(dev_ca)
with open(os.path.join(output_dir, 'dev.ca-en.en'), 'w', encoding='utf-8') as f:
    f.writelines(dev_en)
with open(os.path.join(output_dir, 'test.ca-en.ca'), 'w', encoding='utf-8') as f:
    f.writelines(test_ca)
with open(os.path.join(output_dir, 'test.ca-en.en'), 'w', encoding='utf-8') as f:
    f.writelines(test_en)

# %% [markdown]
# ## Split the ca-es OpenSubtitles parallel corpus into train, dev and test set

# %%
# We need to split the ca-en OpenSubtitles parallel corpus into train, dev and test sets

import os
import random

# Define the path to the files
path_ca = '/content/drive/MyDrive/MT2/ca-en/ca-es.ca'
path_en = '/content/drive/MyDrive/MT2/ca-en/ca-es.es'

# Define the percentages for the train, dev, and test sets
train_percent = 0.7
dev_percent = 0.15
test_percent = 0.15

# Define the output directory
output_dir = '/content/drive/MyDrive/MT2/ca-en'

# Create the output directory if it does not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
# Read the files
with open(path_ca, 'r', encoding='utf-8') as f:
    lines_ca = f.readlines()
with open(path_en, 'r', encoding='utf-8') as f:
    lines_en = f.readlines()

# Compute the sizes of the train, dev, and test sets
size = len(lines_ca)
train_size = int(size * train_percent)
dev_size = int(size * dev_percent)
test_size = size - train_size - dev_size

# Shuffle the lines
random.seed(42)
indices = list(range(size))
random.shuffle(indices)

# Split the lines into train, dev, and test sets
train_indices = indices[:train_size]
dev_indices = indices[train_size:train_size+dev_size]
test_indices = indices[train_size+dev_size:]

train_ca = [lines_ca[i] for i in train_indices]
train_es = [lines_en[i] for i in train_indices]
dev_ca = [lines_ca[i] for i in dev_indices]
dev_es = [lines_en[i] for i in dev_indices]
test_ca = [lines_ca[i] for i in test_indices]
test_es = [lines_en[i] for i in test_indices]

# Write the output files
with open(os.path.join(output_dir, 'train.ca-es.ca'), 'w', encoding='utf-8') as f:
    f.writelines(train_ca)
with open(os.path.join(output_dir, 'train.ca-es.es'), 'w', encoding='utf-8') as f:
    f.writelines(train_es)
with open(os.path.join(output_dir, 'dev.ca-es.ca'), 'w', encoding='utf-8') as f:
    f.writelines(dev_ca)
with open(os.path.join(output_dir, 'dev.ca-es.es'), 'w', encoding='utf-8') as f:
    f.writelines(dev_es)
with open(os.path.join(output_dir, 'test.ca-es.ca'), 'w', encoding='utf-8') as f:
    f.writelines(test_ca)
with open(os.path.join(output_dir, 'test.ca-es.es'), 'w', encoding='utf-8') as f:
    f.writelines(test_es)

# %% [markdown]
# ## Set source and target languages

# %%
# TODO: Set your source and target languages. Keep in mind, these traditionally use language codes as found here:
# These will also become the suffix's of all vocab and corpus files used throughout
import os
from os import path

source_language = "en"
target_language = "ca" 
lc = False  # If True, lowercase the data.
seed = 42  # Random seed for shuffling.
tag = "baseline" # Give a unique name to your folder - this is to ensure you don't rewrite any models you've already submitted

os.environ["src"] = source_language # Sets them in bash as well, since we often use bash scripts
os.environ["tgt"] = target_language
os.environ["tag"] = tag

# This will save it to a folder in our gdrive instead!
# !mkdir -p "/content/drive/MyDrive/MT2"
os.environ["gdrive_path"] = "/content/drive/MyDrive/MT2"

# %%
# !echo "$gdrive_path"
# !mkdir -p "/content/drive/MyDrive/MT2"
# Out:
# /content/drive/MyDrive/MT2

# %% [markdown]
# ---
#
#
# ## Installation of JoeyNMT
#
# JoeyNMT is a simple, minimalist NMT package which is useful for learning and teaching. Check out the documentation for JoeyNMT [here](https://joeynmt.readthedocs.io)

# %%
! pip install -e git+https://github.com/joeynmt/joeynmt.git@1.5#egg=joeynmt
! rm -fr joeynmt
! git clone https://github.com/joeynmt/joeynmt.git --branch 1.5 --single-branch
! pip install torch==1.10.1+cu102 torchtext==0.11.1 -f https://download.pytorch.org/whl/torch_stable.html
! pip install setuptools==59.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining joeynmt from git+https://github.com/joeynmt/joeynmt.git@1.5#egg=joeynmt
#   Cloning https://github.com/joeynmt/joeynmt.git (to revision 1.5) to ./src/joeynmt
#   Running command git clone --filter=blob:none --quiet https://github.com/joeynmt/joeynmt.git /content/src/joeynmt
#   Running command git checkout -q 092c504cb3d7b25b91cc37af4fbfe55af4faf64f
#   Resolved https://github.com/joeynmt/joeynmt.git to commit 092c504cb3d7b25b91cc37af4fbfe55af4faf64f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from joeynmt) (0.18.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from joeynmt) (8.4.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (1.22.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (67.7.2)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (2.0.0+cu118)
# Requirement already satisfied: tensorboard>=1.15 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (2.12.2)
# Requirement already satisfied: torchtext>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (0.15.1)
# Collecting sacrebleu>=2.0.0
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 6.0 MB/s eta 0:00:00
# Collecting subword-nmt
#   Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from joeynmt) (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from joeynmt) (0.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (6.0)
# Collecting pylint>=2.9.6
#   Downloading pylint-2.17.4-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12 in /usr/local/lib/python3.10/dist-packages (from joeynmt) (1.16.0)
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting mccabe<0.8,>=0.6
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting isort<6,>=4.2.5
#   Downloading isort-5.12.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 14.1 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from pylint>=2.9.6->joeynmt) (3.3.0)
# Collecting dill>=0.2
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.7 MB/s eta 0:00:00
# Collecting tomlkit>=0.10.1
#   Downloading tomlkit-0.11.8-py3-none-any.whl (35 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from pylint>=2.9.6->joeynmt) (2.0.1)
# Collecting astroid<=2.17.0-dev0,>=2.15.4
#   Downloading astroid-2.15.4-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 30.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=2.0.0->joeynmt) (4.9.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=2.0.0->joeynmt) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu>=2.0.0->joeynmt) (0.8.10)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (1.54.0)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (3.20.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (1.4.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (0.40.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (3.4.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (2.17.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (0.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (2.27.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (2.3.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->joeynmt) (1.0.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->joeynmt) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9.0->joeynmt) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.9.0->joeynmt) (3.25.2)
# Requirement already satisfied: torchdata==0.6.0 in /usr/local/lib/python3.10/dist-packages (from torchtext>=0.10.0->joeynmt) (0.6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext>=0.10.0->joeynmt) (4.65.0)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.6.0->torchtext>=0.10.0->joeynmt) (1.26.15)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->joeynmt) (23.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn->joeynmt) (1.5.3)
# Collecting mock
#   Downloading mock-5.0.2-py3-none-any.whl (30 kB)
# Collecting lazy-object-proxy>=1.4.0
#   Downloading lazy_object_proxy-1.9.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->joeynmt) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->joeynmt) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->joeynmt) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->joeynmt) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn->joeynmt) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->joeynmt) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->joeynmt) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->joeynmt) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15->joeynmt) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->joeynmt) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15->joeynmt) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->joeynmt) (3.2.2)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.1-cp310-cp310-linux_x86_64.whl size=75837 sha256=73651b11a958e2147843822c7a40e9ca43c39b05aa582247fb60dce20cd820bc
#   Stored in directory: /root/.cache/pip/wheels/85/19/42/69edf7822f9dc97f62b1584a22f342d1474d1bb24fe3cc2bc8
# Successfully built wrapt
# Installing collected packages: wrapt, tomlkit, portalocker, mock, mccabe, lazy-object-proxy, isort, dill, colorama, subword-nmt, sacrebleu, astroid, pylint, joeynmt
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.14.1
#     Uninstalling wrapt-1.14.1:
#       Successfully uninstalled wrapt-1.14.1
#   Running setup.py develop for joeynmt
# Successfully installed astroid-2.15.4 colorama-0.4.6 dill-0.3.6 isort-5.12.0 joeynmt-1.5 lazy-object-proxy-1.9.0 mccabe-0.7.0 mock-5.0.2 portalocker-2.7.0 pylint-2.17.4 sacrebleu-2.3.1 subword-nmt-0.3.8 tomlkit-0.11.8 wrapt-1.11.1
# Cloning into 'joeynmt'...
# remote: Enumerating objects: 3292, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 3292 (delta 10), reused 9 (delta 9), pack-reused 3278
# Receiving objects: 100% (3292/3292), 8.10 MiB | 19.52 MiB/s, done.
# Resolving deltas: 100% (2279/2279), done.
# Note: switching to '092c504cb3d7b25b91cc37af4fbfe55af4faf64f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.10.1+cu102 (from versions: 1.11.0, 1.11.0+cpu, 1.11.0+cu102, 1.11.0+cu113, 1.11.0+cu115, 1.11.0+rocm4.3.1, 1.11.0+rocm4.5.2, 1.12.0, 1.12.0+cpu, 1.12.0+cu102, 1.12.0+cu113, 1.12.0+cu116, 1.12.0+rocm5.0, 1.12.0+rocm5.1.1, 1.12.1, 1.12.1+cpu, 1.12.1+cu102, 1.12.1+cu113, 1.12.1+cu116, 1.12.1+rocm5.0, 1.12.1+rocm5.1.1, 1.13.0, 1.13.0+cpu, 1.13.0+cu116, 1.13.0+cu117, 1.13.0+cu117.with.pypi.cudnn, 1.13.0+rocm5.1.1, 1.13.0+rocm5.2, 1.13.1, 1.13.1+cpu, 1.13.1+cu116, 1.13.1+cu117, 1.13.1+cu117.with.pypi.cudnn, 1.13.1+rocm5.1.1, 1.13.1+rocm5.2, 2.0.0, 2.0.0+cpu, 2.0.0+cpu.cxx11.abi, 2.0.0+cu117, 2.0.0+cu117.with.pypi.cudnn, 2.0.0+cu118, 2.0.0+rocm5.3, 2.0.0+rocm5.4.2, 2.0.1+cpu, 2.0.1+cpu.cxx11.abi, 2.0.1+cu117, 2.0.1+cu117.with.pypi.cudnn, 2.0.1+cu118, 2.0.1+rocm5.3, 2.0.1+rocm5.4.2)
# ERROR: No matching distribution found for torch==1.10.1+cu102
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 36.2 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# cvxpy 1.3.1 requires setuptools>65.5.1, but you have setuptools 59.5.0 which is incompatible.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# Successfully installed setuptools-59.5.0

# %% [markdown]
# ## Prepare the training data
# Combine low-resourced langauge (ca) and high-resourced language (es) to get the best training data possible

# %%
# copy data from your own Drive 
from os import path

# Replace "source_language" and "target_language" with the language codes of your choice
source_language = "en"
target_language = "ca"

# Set the path to the data files on your Google Drive
data_drive_path = "/content/drive/MyDrive/MT2/ca-en"

# Set the destination path for the data files in the Colab environment
data_path = path.join("joeynmt", "data", source_language + target_language)
os.environ["data_path"] = data_path

# Create the destination directory if it does not exist
# !mkdir -p $data_path

# Copy the data files from your Google Drive to the destination directory
# !cp -r "$data_drive_path"/* $data_path/

# %%
'''# copy data from your onw Drive 
from os import path

data_path = path.join("joeynmt", "data", source_language + target_language)
os.environ["data_path"] = data_path

# !mkdir -p $data_path
# !cp /content/drive/MyDrive/MT/ca-en/* $data_path'''

# %%
# back-translation
# !pip install sentencepiece
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.0 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 85.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1

# %% [markdown]
# # Generate bpe model

# %%
# !cat $data_path/train.ca-en.en $data_path/train.ca-en.ca | subword-nmt learn-bpe -s 20000 -o bpe.codes
# Out:
# 100% 20000/20000 [00:50<00:00, 393.08it/s]

# %%
# !cat $data_path/train.ca-es.es $data_path/train.ca-es.ca | subword-nmt learn-bpe -s 20000 -o esbpe.codes
# Out:
# 100% 20000/20000 [01:07<00:00, 294.39it/s]

# %% [markdown]
# #Backtranslation: translate CA –> ES

# %%
# load target language monolingual data into src_text

from transformers import MarianTokenizer, MarianMTModel
from transformers import pipeline
from typing import List

#load the model from https://huggingface.co/Helsinki-NLP
model_name = 'Helsinki-NLP/opus-mt-ca-es'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/281M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/807k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/811k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.15M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# Translate data: 
monolingual_ca = open('/content/drive/MyDrive/MT2/ca-en/train.mono.ca', 'r').readlines()
tgt_file = open('/content/drive/MyDrive/MT2/ca-en/train.bcktr.es', 'w', )
for line in monolingual_ca[:10000]: # Delete '[:200]' to translate everything –> Adapt size to computing power
  input = tokenizer(line, return_tensors="pt", padding=True)
  translated = model.generate(**input)
  tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
  #print(tgt_text)
  #print(type(tgt_text))
  tgt_file.write(tgt_text[0] + '\n')
tgt_file.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
# apply BPE model to the split of the monolingual EN data

monolingual_ca = open('/content/drive/MyDrive/MT2/ca-en/train.mono.ca', 'r').readlines()

with open("split.train.mono.ca", "w") as src_file:
  for text in monolingual_ca[:249]:
    src_file.write(text)
# !subword-nmt apply-bpe -c '/content/bpe.codes' < split.train.mono.ca > split.train.mono.bpe.ca

# %%
# apply BPE model to backtranslated data
# !subword-nmt apply-bpe -c '/content/esbpe.codes' < '/content/joeynmt/data/enca/train.bcktr.es' > train.bcktr.bpe.es

# %%
# !cat $data_path/train.bcktr.bpe.es
# Out:
# s@@ ai@@ d h@@ ad@@ dad : s@@ ai@@ d h@@ ad@@ dad, gu@@ ado kh@@ ali@@ l haw@@ i.
# sobre el cielo y la tierra (@@ en cast@@ ell@@ ano@@ )@@ .
# la causa del sufri@@ miento es el deseo (@@ segunda verdad nob@@ le@@ )@@ .
# Yo tengo cuidado de mí y me hago responsable de mis acciones decisi@@ vas.
# (@@ no me lo dig@@ as@@ ) y m@@ ne to ne@@ ho@@ v@@ or (@@ no es a mí a quien lo tienes que decir@@ )@@ .
# sé que he usado la palabra compromis@@ o mucho en esta re@@ visi@@ ón, pero eso es lo que tiene el lu@@ mia 5@@ 10.
# versión en línea (@@ ingl@@ és@@ )
# i@@ se (@@ Gar@@ ant@@ ía, i@@ se@@ ?@@ )
# ¿Cómo puedo matar a mi líder y amigo?
# en las montañ@@ as ta@@ í@@ g@@ et@@ os: mes@@ sa@@ pe@@ es (@@ lat@@ ín mes@@ sa@@ pe@@ a@@ e@@ )@@ .
# después de la muerte, un si@@ m no apar@@ ece más vivo (@@ aunque se puede resu@@ ci@@ tar@@ )@@ .
# No estaban som@@ eti@@ dos a malos us@@ os ni a servi@@ du@@ m@@ bres.
# 200@@ 7 esta tampoco será el fin del mundo.
# (@@ las acciones de i@@ van el terrible se descri@@ ben con as@@ co, sin embar@@ go@@ .@@ )
# ¡@@ incluso en sus batall@@ as, están all@@ í!
# No es cre@@ ada ni cre@@ adora.
# debido a que tenía que sentir pena por ed@@ w@@ ard@@ ...
# I@@ bar@@ z, mer@@ ced@@ : la mujer err@@ r@@ ante.
# Pero, ¿es buena mor@@ al?
# sólo fran@@ za puede ahora ofrecer@@ me la protección necesari@@ a...
# ¡No vas a co@@ lli@@ j@@ ar!
# vo@@ h@@ u man@@ ah (@@ buena ment@@ e@@ )@@ , quien da la bienvenida a los de@@ votos dentro del paraí@@ so.
# Ni siquiera es algo que cualquiera puede hablar aquí en el su@@ dan del sur@@ , en particul@@ ar.
# ella conocía an@@ nie ma@@ e person@@ almente.
# Sólo les expli@@ co la verdad y piensan que es el infierno.
# Tal vez c. será record@@ ada como el gran amor de mi vida.
# Sin embargo, todas tienen que estar de acuerdo, o la madre mar@@ ie no in@@ sis@@ tir@@ á.
# ¿Cómo pueden neg@@ arlo?
# bri@@ an vol@@ land ta@@ k@@ es on err@@ ó...
# ¡Un su@@ cos@@ o trozo de carne ha caído a tu bol@@ !
# Yo dij@@ e: en una palabra, ge@@ or@@ ge, drogas.
# i@@ ris@@ h volun@@ te@@ er@@ s@@ ; sobre la organiz@@ ación.
# ella dijo que le gustaba el presidente si@@ ri@@ o.
# (@@ ch@@ oy@@ ) cuando llega a una cr@@ esta consecu@@ tiva, hab@@ iendo recor@@ ri@@ do un vall@@ e.
# Si esto es una emerg@@ encia, dejamos un mensaje.
# Y tú estarás en mer@@ ce@@ d de las ol@@ as y de tus asoci@@ aciones.
# Si eran inspir@@ ados, ¿por qué no también la bibli@@ a y el Cor@@ án?
# De@@ pend@@ en sobre ti - vuestros esfuerz@@ os, su determin@@ ación, su volun@@ tad de sobrevivi@@ r@@ !
# la u@@ e nav@@ f@@ or busc@@ a, cuando es posible, un final legal.
# trabajar 15 horas al día constru@@ ye a un hombre.
# la ley alem@@ ana llevó paz y orden por primera vez...
# gracias por su respuesta gener@@ osa.
# Presidente mi@@ cha@@ el d prom@@ is@@ es se@@ ven y@@ e@@ ars of ne@@ w ide@@ as.
# a través de una mirada a la human@@ idad de cris@@ t - él también murió.
# escri@@ bes que estás ansi@@ osa sobre si habrá una guerra nucle@@ ar entre nuestros paí@@ ses.
# o@@ pu@@ s: the d@@ ay w@@ e fo@@ un@@ d e@@ ar@@ th (@@ en cast@@ ell@@ à@@ )@@ .
# para nuestros hijos y para ti, sam@@ ant@@ ha.
# a mamá mar@@ ia, estos dos elem@@ entos - servicio a los pobres y te@@ ología - iban del br@@ aci@@ to.
# 200@@ 8 (@@ franc@@ és@@ ) vo@@ ir dec@@ í@@ os, la visi@@ on m@@ y@@ sti@@ que.
# estas afir@@ m@@ aciones eran en gran medida in@@ jus@@ tas.
# un 9@@ 6@@ % recomend@@ aba más bús@@ queda.
# la u@@ e es un importante ♫ incluso un T@@ AB@@ AS@@ A@@ influ@@ ente@@ ' T@@ AB@@ AS@@ A ac@@ tor en negoci@@ aciones medi@@ o@@ ambien@@ tales inter@@ nacion@@ ales.
# América debería estar llor@@ ando.
# gr@@ ö@@ n@@ ing también escuch@@ ó@@ :@@ ... un bebé llor@@ ando.
# V@@ end@@ rell@@ , x. disculp@@ en las molesti@@ as ed.
# ¡Todos los que vinieron a may@@ d@@ an, bien hec@@ ho!
# ¡@@ K@@ ed@@ ar@@ n@@ at@@ h prom@@ o@@ ti@@ ons star@@ t!
# estado de la cuestión y a@@ porta@@ cion@@ es@@ )@@ .
# son greg@@ ari@@ as hasta su ter@@ cero inst@@ ar.
# Me gusta el hecho de que estoy trabajando para el director bon@@ g.
# ¿Por qué es la edad media de los o@@ pon@@ entes más baja que la de nuestro equipo nacion@@ al?
# pero la respuesta correc@@ ta no es 1.@@ 4 sino 1@@ 4.
# He oído a los hombres blancos decir que no habrá más guerra.
# Tiene que prove@@ er@@ : una presión inter@@ na estable.
# la observ@@ at@@ oria ne@@ er@@ land@@ és del raci@@ s@@ mo y la x@@ en@@ of@@ ob@@ ia. Est@@ aría un total de 10@@ 6 incid@@ entes viol@@ entos contra obje@@ tivos mu@@ sul@@ man@@ es en novi@@ embre.
# (@@ 5 mar@@ zo de 20@@ 13@@ ) reci@@ pro@@ ci@@ dad w@@ ave ar@@ t competi@@ ti@@ on.
# entr@@ añ@@ able tem@@ or.
# No pronunci@@ en este nombre en mi pres@@ encia.
# 200@@ 4 yo también soy ca@@ tal@@ ana.
# de b@@ ei@@ j@@ ing hasta aquí ha sido un largo viaje.
# red game wit@@ ho@@ ut a gre@@ at n@@ ame (@@ en cast@@ ell@@ ano@@ )@@ .
# Tu señor lí@@ o be@@ i ha sido captur@@ ado.
# la sec@@ ción vi@@ e especi@@ fica las responsabili@@ dades fis@@ cal@@ es de bi@@ el@@ or@@ ru@@ sia.
# el objetivo principal era salvar alm@@ as para Dios.
# anteri@@ or@@ mente, el far@@ a@@ ón era considerado como di@@ vino sólo en la muerte.
# la información rel@@ ativa al estu@@ dio debe estar disponi@@ ble públi@@ camente (@@ artículo 16@@ )@@ .
# el libro acaba con las opini@@ ones de 2@@ 8 exper@@ tos.
# ¿Es la nueva mujer todavía un hombre homosexu@@ al?
# posi@@ blemente quiere la paz, al menos tempor@@ almente.
# ella y yo hemos hablado sobre diferentes cosas.
# Eso requer@@ iría dos más@@ car@@ as@@ /@@ mat@@ tas.
# ¡S@@ rat@@ ford sí!
# mu@@ sul@@ man@@ es, su sig@@ lo muere con vosotros.
# Quiere hablar con f@@ au@@ l@@ hab@@ er.
# 30@@ 6 y 30@@ 9 publi@@ có sus propios edic@@ tos en que exig@@ ía sacrifici@@ o univer@@ sal.
# y se publi@@ car@@ á también la tercera adap@@ tación.
# lar@@ r@@ y viking@@ o: que ir@@ óni@@ co.
# él dijo que hay man@@ er@@ as...
# más tarde, ni@@ k@@ ki gi@@ o@@ van@@ ni tuvo un efecto similar en mí.
# ¿Crees que lo v@@ ati@@ can@@ o me hace ver@@ güenz@@ a?
# jo@@ an pr@@ ados dijo: cuando agarr@@ é una pied@@ ra, es sólo una pied@@ ra.
# ¿Es esta la línea que han cre@@ ado por agr@@ esión desde principi@@ os de sep@@ tiem@@ bre?
# ¿A@@ re guin@@ ea pi@@ g@@ s rod@@ ents?
# ¡B@@ ok@@ u ga er@@ os@@ u de er@@ os@@ u ga bo@@ k@@ u de!
# su há@@ bi@@ tat ha sido redu@@ cido o alter@@ ado.
# no todos los comand@@ antes rusos estaban en estado de pá@@ nico.
# Di@@ jo@@ : no podemos elegir únic@@ amente cuesti@@ ones particul@@ ares.
# 2@@ ,@@ 5@@ 4@@ 9@@ -@@ 5@@ 2 que su trabajo fue inter@@ rumpi@@ do después de seis libr@@ os.
# de hecho, me doy perfectamente que mi ev@@ entu@@ al san@@ ción puede au@@ mentar por mi conduc@@ ta present@@ e...
# en mar@@ io sigue siendo el rey en 2@@ d... por ahora.
# rom@@ m@@ el tarda poco tiempo en lan@@ zar su propia ofensi@@ va el 3@@ 1 de mar@@ zo.
# pre@@ pá@@ ren@@ se a sus descen@@ dientes para el futuro.
# así es como me miro mi@@ ke@@ y, como una persona compl@@ ej@@ a.
# G@@ á@@ s@@ tate 1.@@ 9@@ 9@@ ≤ y muere tantas veces como quieras.
# el g@@ he fue nacion@@ aliz@@ ado el 30 de jun@@ io de 194@@ 6, junto con sus instal@@ aciones r@@ est@@ antes y edifici@@ os.
# en 198@@ 8 fueron los presen@@ tador@@ es de hola, hola 8@@ 9.
# juli@@ a ch@@ il@@ d@@ : li@@ fe be@@ for@@ e fr@@ enc@@ h cu@@ is@@ ine.
# mar@@ cas cultur@@ ales todavía se pueden encontrar per@@ o.
# es ahora una alcohol@@ ica que vive en el pasado.
# Los paci@@ entes trata@@ ban tanto individu@@ almente como en gru@@ pos.
# '@@ ma@@ k@@ hu@@ w@@ a'@@ , pero no son consi@@ st@@ entes.
# llor@@ ente pic@@ ks no 14 sh@@ ir@@ t?
# Necesitamos interpre@@ tar@@ lo pres@@ ici@@ mo, o, mejor a@@ ú@@ n, viv@@ aci@@ sim@@ o.
# ar@@ ab@@ ia be@@ for@@ e mu@@ ham@@ mad@@ .
# Tambi@@ én, la esclavi@@ tud habría sido exclu@@ ida de mis@@ so@@ u@@ ri@@ ...
# a él le encan@@ tan estos person@@ ajes y es un fanta@@ sti@@ co escritor@@ ...
# ¿@@ w@@ her@@ e di@@ d de so@@ to land@@ ?
# Sin embargo, az@@ er@@ bai@@ y@@ án ha declar@@ ado continu@@ amente que está interesado en una solu@@ ción diplom@@ ática y pacífic@@ a.
# Si ves que fal@@ tan algunas págin@@ as, entonces es tu deber encontr@@ arlas.
# la k@@ erry y yo pensamos que hacer los 70 que fal@@ tan.
# si esa persona nació en un país extran@@ jer@@ o... a.
# la alcal@@ desa que trajo la ni@@ eve (@@ en cast@@ ell@@ ano@@ )@@ .
# en ver@@ ano, la irri@@ g@@ ación era impres@@ cin@@ di@@ ble.
# ¡@@ nadie reemplaz@@ ará tu reino de ts@@ ar cristi@@ an@@ o!
# somos parte de la eur@@ oz@@ ona muchos derechos y muchas oblig@@ aciones.
# por la mañana habrá ni@@ eb@@ la bajo la tierra.
# Sólo he cometido el error de creer en ustedes, los americ@@ anos.
# ¡Eso significa que realmente am@@ aba a sueñ@@ o!
# Incluso si tienes un rastro de sangre indi@@ a, ¿por qué quieres selec@@ cion@@ arla por su ident@@ idad, y no ir@@ land@@ és o itali@@ ano?
# ser un b@@ a'@@ al te@@ ki@@ ah es un honor.
# las autor@@ idades por@@ tu@@ gu@@ esas mataron a 4@@ 9 personas el 5 de fe@@ br@@ ero.
# person@@ almente, yo odio a los japon@@ eses.
# 2@@ .@@ 0@@ 25 la sust@@ ancia es forma y conten@@ ido...
# Dej@@ é la universidad porque no me gusta@@ ba.
# la elección de 1@@ 15@@ 9 también tuvo consecu@@ encias leg@@ ales signific@@ ativ@@ as.
# sonido w@@ ha@@ t (@@ y qué@@ )@@ .
# Sin embargo, sólo los árbol@@ es hem@@ bra produc@@ en estos fru@@ tos.
# 1@@ 20@@ 1 ya no era lo suficientemente poderoso para el nuevo mod@@ elo.
# 15@@ 4@@ 5, bas@@ ado en un examen de la evolu@@ ción del estilo de br@@ on@@ z@@ ino, que sugi@@ ere gi@@ o@@ van@@ ni.
# pronto ab@@ ol@@ ió todos los rein@@ os tradi@@ cion@@ ales u@@ gan@@ des@@ es, inclu@@ ido tor@@ o.
# Él no sabe cómo cl@@ asi@@ ficar esta cuar@@ ta edad.
# se regis@@ tra que pocas personas entre 6 y 15 años no pueden leer la bibli@@ a.
# Sin embargo, el protec@@ cion@@ ismo para ambos l@@ ados puede ser una barr@@ era para cualquier acuerdo futuro.
# (@@ ¡@@ victor@@ ia! ) como si quisiera asus@@ tar a todos los enemigos de delante de ellos.
# Él creía que eur@@ op@@ a podría adop@@ tar una religi@@ ón uniforme.
# No queréis que haga nada, excepto canción de hielo y fuego.
# Gol@@ den s@@ un ds fue anunci@@ ado.
# a t-@@ on déj@@ à v@@ u un co@@ q man@@ ger un li@@ on? (@@ en franc@@ és@@ )@@ .
# no se le as@@ ig@@ na música con cer@@ te@@ za.
# ¿@@ ys homosexu@@ al@@ it@@ y a par@@ ap@@ hi@@ li@@ a?
# Nadie pudo record@@ arla como una bailar@@ ina fam@@ osa.
# está en 19@@ 6@@ 4, así que todo se ve realmente diferente.
# Fue con los gri@@ eg@@ os@@ ; entonces murió con ellos (@@ ?@@ ) o en el ♫@@ um@@ to.
# no sean sever@@ os con vuestros hombres o con sus ofici@@ ales, a los que deberían consul@@ tar sobre cada asunto.
# pase lo que pase en el futuro, nunca se convertir@@ á en el presidente legíti@@ m@@ amente elec@@ to de uc@@ ran@@ ia.
# N@@ ain@@ ado, paj@@ on@@ es: tre@@ ce que cant@@ an.
# las fuerzas del gobierno lo hizo mucho, muy clar@@ o...
# es llamado para solu@@ cionar el caso a aur@@ ora.
# También sería un primer paso a una feder@@ ación eur@@ ope@@ a.
# 6@@ .000 sir@@ ven en la policía de alerta.
# nadie, ni a w@@ as@@ hing@@ ton ni a vi@@ etn@@ am, se esperaba lo que pas@@ aría.
# un 7@@ 5@@ % de su tráfico viene de fuera de t@@ wit@@ ter@@ .@@ com@@ .
# Dijo que la misión era estric@@ tamente human@@ itar@@ ia.
# las autor@@ idades (@@ o ma@@ kh@@ z@@ en@@ ) neg@@ aron todas estas acus@@ aciones.
# Sw@@ ine un pir@@ ata australi@@ ano que trabaja por j@@ ak@@ e.
# Ahí ayud@@ ó a crear la I@@ ra 1@@ 10@@ 3.
# el hotel b@@ el@@ mon@@ t también se puede ver.
# es un en@@ fo@@ que diferente para mí, o para t@@ hor@@ .
# los detalles sobre los ev@@ entos m@@ auri@@ tan@@ os de 3@@ 9@@ -@@ 4@@ 4 no son clar@@ os.
# el país val@@ enci@@ ano al rit@@ mo de los abri@@ endo paso.
# pe@@ ano@@ : li@@ fe and wor@@ ks of gi@@ u@@ sep@@ pe pe@@ ano (@@ en ingl@@ és@@ )@@ )@@ .
# ar@@ gent@@ ina bus@@ caba mejor@@ ar las relaciones comerci@@ ales.
# el autom@@ ó@@ vil de hidr@@ ó@@ gen@@ o, aunque a menudo in@@ corpor@@ a algunos de los mismos elem@@ entos.
# un col@@ gan@@ te de co@@ bre fue la única prueba de rique@@ za que descubri@@ ó.
# g@@ et pr@@ ag@@ ma@@ ti@@ c ab@@ ou@@ t pot (@@ ingl@@ és@@ )@@ .
# También se re@@ vela que mem@@ a ha estado viendo a un hombre cas@@ ado, carter@@ o.
# los trabaj@@ os de este perio@@ do inclu@@ y@@ en un@@ ici@@ o on@@ de@@ ; un@@ der@@ wood@@ ; bl@@ u@@ e lad@@ y.
# antes de 194@@ 8 era solo un visi@@ tante in@@ vern@@ al.
# ¡Te dije que era '@@ whisk@@ as@@ '@@ !
# el a@@ aron lo podía haber hecho de todos modos.
# Quizás voy hacia otro papel w@@ agn@@ eri@@ ano - ¿quién sabe?
# Por cierto, ¿@@ ves los plane@@ tas?
# pobl@@ ados ár@@ ab@@ es: al@@ -@@ az@@ y (@@ Gar@@ ant@@ ía - In@@ for@@ me@@ )@@ .
# 2@@ 6@@ -@@ 3@@ 6@@ )@@ , probablemente después de la gran comi@@ sión.
# la cre@@ encia en el día del juicio (@@ q@@ i@@ y@@ am@@ a@@ )@@ .
# Le defender@@ án contra cualquiera con sus armas.
# ¿Cómo se produc@@ e esa de@@ valu@@ ación y por qué es eso ni@@ hi@@ lis@@ ta?
# apar@@ atos de televisi@@ ón@@ : na@@ ; probablemente menos de 1,@@ 000 (@@ 199@@ 7@@ )@@ .
# Por@@ tu@@ gal@@ : sh@@ ado@@ w tol@@ l s@@ yst@@ em is re@@ plac@@ ed.
# muchos ban@@ cos centr@@ ales han adop@@ tado un objetivo de infl@@ ación.
# Era mi propia manera de defender@@ me@@ : proteger@@ me del mundo exterior.
# apar@@ ece por ser el miembro de tripul@@ ación más joven (@@ a parte de tom@@ o@@ )@@ .
# su prior@@ idad en todo momento es el bien@@ estar y la estabili@@ dad del equipo del aras i@@ i@@ i.
# Si dios no me olvid@@ a@@ ) amiga (@@ baj@@ o@@ )@@ : au@@ f got@@ t st@@ eh@@ t me@@ ine z@@ u@@ versi@@ ch@@ t (@@ en dios pongo mi confi@@ anz@@ a@@ ) reci@@ ta@@ tivo (@@ contr@@ alt@@ )@@ : e@@ i nun@@ !
# Tal vez incluso volveré a escribir algunas cos@@ as...
# la resol@@ u@@ ción actual no fue impl@@ em@@ en@@ tada y la resol@@ u@@ ción 14@@ 0@@ 3 exig@@ ió su impl@@ em@@ en@@ tación.
# ni@@ ger@@ ía s@@ ame sex mar@@ ri@@ ag@@ e bill@@ -@@ final.
# Cre@@ ían que la sur@@ a chi@@ i del Cor@@ án (@@ y@@ ú@@ su@@ f@@ ) no era autén@@ ti@@ ca.
# el ch@@ inos descubri@@ eron esta gran escap@@ e dos días más tarde.
# n@@ am@@ go@@ on@@ g@@ ... es difícil.
# ah@@ ti@@ sa@@ ario rápi@@ damente decidió permitir un des@@ pli@@ egu@@ e limi@@ tado.
# ¡@@ Nosotros lo haremos por usted en seis minu@@ tos!
# sólo los 26 paí@@ ses pr@@ esta@@ tari@@ os pueden recibir pr@@ és@@ tamos.
# la iglesia siempre ha tenido el honor de esta opción prefer@@ encial para los po@@ br@@ es...
# ya no cu@@ bre ne@@ w@@ ton.
# Si un niño puede salir a las dos de la mad@@ rug@@ ada, también puede hacerlo una chica, dijo.
# un informe de 199@@ 8 de la as@@ am@@ bl@@ ea nacional franc@@ esa present@@ ó dos explic@@ aciones prob@@ ables.
# g@@ m, al parec@@ er, no quería o@@ pel@@ .
# ¡El resto es vulner@@ able!
# Jack claramente sabe quién es el responsable pero es también seguro que sólo él puede identificar al culpable.
# No necesitamos exac@@ er@@ b@@ aciones según el represent@@ ante sud@@ af@@ ri@@ can@@ o pi@@ k bo@@ cha.
# otra es propiedad de la empres@@ ari n@@ el@@ son bli@@ tz@@ , y una fue compr@@ ada en 199@@ 9 por st@@ ev@@ en a. co@@ h@@ en.
# ¿Qué le di@@ remos que le sepa buen@@ o?
# Nunca permiti@@ mos que las empres@@ as ch@@ inas y los ciudadanos viol@@ en las resol@@ u@@ ciones.
# también es posible 1@@ ...@@ b@@ 5@@ !@@ ?@@ , una forma de defensa pol@@ aca.
# la muerte ha tenido lugar en cuatro de los 10@@ 7 casos confir@@ mad@@ os.
# boti@@ a i munici@@ esa també viaj@@ an a la final de rom@@ a (@@ en cast@@ ell@@ à@@ )@@ .
# cada ob@@ is@@ po ir@@ land@@ és habló durante unos cinco minutos.
# Todavía tengo ad@@ ren@@ al@@ ina en la sangre.
# las provisi@@ ones que los de@@ porta@@ dos habían llevado con ellos pronto se consu@@ mir@@ on...
# garanti@@ zo a todos los cristi@@ anos de jer@@ us@@ al@@ én los mismos derechos que disfru@@ tan los mu@@ sul@@ man@@ es.
# para evitar que esto volvi@@ era a suced@@ er, par@@ edes se convirtió ofici@@ almente en una calle de bar@@ cel@@ ona en 13@@ 8@@ 6.
# ciudad ar@@ gent@@ ina, b@@ s.
# Él nunca fue a la igles@@ ia, pero solo por raz@@ ones políti@@ cas.
# Teníamos que explicar el gal@@ ax@@ y s i@@ i@@ i con todo tipo de palabras.
# cero o más consu@@ mi@@ dores pueden recibir el mensaje.
# la cu@@ p ren@@ u@@ eva el 40@@ % de los di@@ pu@@ tados que tiene en el parl@@ amento.
# también descri@@ be el número 11@@ 7 como un número atrac@@ tivo.
# cre@@ amos era mejor que eso...
# Pregún@@ ta@@ lo a tu supervis@@ or.
# il@@ us versión 6@@ .@@ 0@@ 5
# Lo llamamos con músi@@ ca@@ : ¡no a la pena de muer@@ te@@ !@@ .
# un distin@@ tivo sí fue la respuesta de lu@@ ter.
# los trabaj@@ adores del campo del dón@@ u fueron captur@@ ados en un cat@@ ch@@ -@@ 2@@ 2.
# an@@ gol@@ a, muestra la mism@@ a, aún más pronunci@@ ada.
# mad@@ hu@@ k@@ u no@@ w fu@@ ll profes@@ or.
# Yo estaba pensando en ed@@ ward cuando lo hice r.
# ejempl@@ os: er@@ or@@ i n@@ ai@@ z (@@ he caigu@@ t@@ )@@ , er@@ or@@ i da (@@ ha caigu@@ t@@ )@@ , er@@ or@@ i di@@ ra (@@ han caigu@@ t@@ )@@ .
# éste fue precis@@ amente el momento en que esper@@ aban a los is@@ ra@@ el@@ í@@ es.
# 19@@ 1@@ 1, ed@@ ward consiguió un trabajo a@@ eg@@ .
# Esto significa que li@@ tu@@ an@@ ia se hace más ri@@ ca, más espiritu@@ al que econ@@ ó@@ mi@@ cam@@ ente.
# 2@@ 3@@ ,@@ 7 gram@@ os@@ ) que los últi@@ mos.
# pero este es sólo uno de mis al@@ ter eg@@ os.
# Escri@@ bió un informe de 3@@ 2 págin@@ as, justo después de la batalla.
# en su pá@@ gina oficial también se refer@@ ían a sí mismos como mon@@ th@@ ly che@@ es@@ e@@ !@@ .
# Nunca me pregunté por qué is@@ ra@@ el había muerto a mi padre.
# en 200@@ 9, las fuerzas an@@ gol@@ osas mataron ar@@ bi@@ tr@@ ari@@ amente a 6@@ 1 personas.
# También estaban suj@@ etos a la c@@ ens@@ ura (@@ gu@@ t@@ man, p@@ p@@ .@@ 11 )@@ .
# bajo ch@@ ri@@ sti@@ an s@@ ch@@ war@@ z@@ -@@ s@@ chill@@ ing el oh@@ r parecía su@@ avi@@ zar su invasi@@ vi@@ dad, gracias a presi@@ ones del consejo de eur@@ op@@ a y una impli@@ c@@ ación creci@@ ente de la u@@ e.
# ¿@@ I@@ s ir@@ a@@ q@@ i k@@ ur@@ dist@@ án a go@@ od all@@ y?
# j@@ ac@@ ques du@@ pu@@ is y su trabajo sobre el pl@@ ur@@ alis@@ mo religi@@ oso.
# les@@ ier@@ ta único color ari@@ stoc@@ r@@ áti@@ co...
# Él estaba muy enfad@@ ado con los is@@ ra@@ el@@ í@@ es.
# ¿Qué or trai@@ tor?
# otra opción es jugar 6@@ ...
# lo como y el porqué de la nueva presen@@ tación de las men@@ inas.
# un ej@@ emp@@ lo reci@@ ente es el acuerdo gri@@ ego de res@@ cate de ma@@ yo de 20@@ 10.
# Aunque des@@ conocido por sig@@ mun@@ d, este es el dios od@@ in.
# ¡Y@@ ,@@ 3@@ 1, canción adi@@ ós!
# un planeta gig@@ ante es cualquier planeta m@@ asi@@ vo.
# ¿Por qué no podemos morir todos juntos?
# usa listos g@@ abi@@ el m@@ ach@@ t f@@ or a legal min@@ d.
# su canción y analiz@@ a su fe cristi@@ ana.
# los bas@@ cos son un pueblo muy antigu@@ o...
# Sin embargo, el inver@@ so también se ha observ@@ ado, como en la estrella des@@ ig@@ nada como h@@ d 3@@ 199@@ 3@@ .@@ )
# También se dice que mar@@ gar@@ eto invi@@ tó o cuid@@ ó a dos hu@@ ér@@ f@@ anos durante esta fiesta.
# (@@ 12 competi@@ ciones fueron cancel@@ adas debido a las dos guerr@@ as mundi@@ al@@ es@@ .@@ )@@ .
# ¡@@ w@@ ha@@ t a ha@@ p@@ p@@ y se@@ t!
# los in@@ migr@@ antes japon@@ eses llegaron pos@@ terior@@ mente.
# a partir del 15 de sep@@ tiem@@ bre de 200@@ 6, la misión funcion@@ aba en una confi@@ gur@@ ación de 3@@ 6 monitor@@ es.
# ni siquiera después del 200@@ 3 o 200@@ 6@@ .@@ 0@@ 8@@ 1,@@ 40
# ¿Hay formas emocion@@ ales que podemos asoci@@ arse con la domin@@ ación soci@@ al?
# cientos años : un geni@@ o román@@ tico.
# (@@ el estado ha re@@ conocido ocho tri@@ bus@@ .@@ )
# otros trabaj@@ os ac@@ adé@@ mi@@ cos son@@ : (@@ 198@@ 5@@ ) the i@@ ris@@ h lan@@ gu@@ ag@@ e.
# Él quería que fuera mejor que las otras sin@@ fon@@ ías.
# es sólo el tercer lugar, un br@@ onc@@ e.
# la oficial mexic@@ ana y la que se convirtió en inter@@ nacional por error.
# la policía esp@@ añ@@ ola aban@@ dona la se@@ de de la cu@@ p ocho horas después sin haber podido entrar (@@ en ca@@ )@@ .
# Si per@@ dem@@ os, seré el rey de itali@@ a.
# No parece que ningún miembro de la familia i@@ b@@ el@@ in se haya ido a otro país en este perio@@ do.
# Yo hablo por mí mismo, porque yo soy libre.
# Los histori@@ adores saben menos sobre las ru@@ tas mar@@ íti@@ mas.
# el raci@@ s@@ mo existi@@ ó en casa en fran@@ za, pero no lo vi.
# Estamos luchando la guerra del pa@@ k@@ ist@@ án en esta pro@@ vin@@ ci@@ a...
# Buenos días.
# la comun@@ idad críti@@ ca, fran@@ camente, nos fue muy útil.
# Tur@@ qu@@ ía tiene razón de querer mantener sus fronter@@ as segur@@ as.
# probablemente mill@@ er escribió algunos de los arreg@@ los junto con mac@@ greg@@ or.
# las personas tom@@ an demasiado seri@@ amente sus fracas@@ os.
# Quería llev@@ arse a Si@@ d con ella...
# Además, más de 30 000 personas de cada reg@@ ión tienen que firmar la peti@@ ción, incluso la capital min@@ s@@ k.
# ¡@@ Nuestra gener@@ ación ya no servir@@ á a la muerte y la destruc@@ ción!
# Aunque no hemos viaj@@ ado a todos los plane@@ tas ni al sol, conocemos sus mas@@ as.
# Solo un hombre, tú@@ an ma@@ c cai@@ ri@@ ll@@ , sobre@@ viv@@ e.
# Esto se podría interpre@@ tar diciendo simplemente que es siempre más oscuro antes del aman@@ ec@@ er, pero las buenas cosas están en camino.
# Sin embargo, la respuesta de is@@ ra@@ el fue inmedi@@ ata y cont@@ und@@ ent@@ e: no habría negoci@@ ación.
# niño significa una persona menor de 21 años que nunca ha sido cas@@ ada.
# 3 habría sido demasiado po@@ cos.
# durante este tiempo él también cre@@ ó man se@@ at@@ ed wit@@ h trav@@ el ba@@ g (@@ c.
# pero ella también dijo: no soy la presid@@ enta de har@@ v@@ ard, soy el presidente de har@@ vard.
# segundos j@@ on@@ ed@@ as@@ : entró con el pelo ver@@ de.
# el plan de acción de bio@@ diver@@ si@@ dad in@@ don@@ es@@ is de 199@@ 3 recomend@@ ó la des@@ ign@@ ación de una zona protegi@@ da integr@@ ada.
# mur@@ r@@ y w@@ il@@ son dec@@ ía, era muy listo y rápido.
# 8@@ 7, sec@@ ción 15@@ 5 cu@@ bre leg@@ almente el lesbi@@ an@@ is@@ mo.
# Se han gas@@ tado más de 11 millones $@@ , en la re@@ habili@@ tación de tali@@ es@@ in desde 199@@ 8.
# si@@ ma q@@ i@@ an a menudo cita sus fu@@ entes.
# la música or@@ qu@@ esta@@ l o sin@@ f@@ ón@@ ica nunca me interes@@ ó.
# el informe ri@@ de pro@@ pon@@ ía cuatro inici@@ ati@@ vas principal@@ es para estu@@ dio y evalu@@ ación.
# diam@@ on@@ d también fue registr@@ ada en l@@ on@@ dr@@ es.
# el trabajo de mez@@ cl@@ an a menudo la llevó fuera de la universidad.
# También hay un final /@@ tox@@ /@@ , escri@@ ta er.
# la correspon@@ d@@ encia de pit@@ ch@@ lyn@@ n muestra también que estaban discu@@ tiendo la necesidad de una escuela de chicas.
# actu@@ almente es la única universidad a@@ ustri@@ aca que no tiene la palabra universidad en su nombre.
# El 80@@ % dec@@ ían que podrían trabajar en el extran@@ jero de todos modos, car@@ o todo el mundo habla inglés.
# Marie lo@@ y@@ d@@ : el y só@@ lo.
# (@@ el niño ve su cas@@ a@@ .@@ )
# fi@@ fa pro@@ fi@@ le la de@@ cada del 20
# Sólo soy una chica de un par@@ que de carav@@ anas que tuvo un sueño.
# En realidad, una ola de calor puede haber caus@@ ado amb@@ as.
# ¿o esper@@ as orden@@ es de la ha@@ van@@ a?
# El ferrocarri@@ l b@@ az@@ a-@@ uti@@ el, una obra que empezó hace medio sig@@ lo.
# desde entonces no he recibido nada más que amor y apo@@ yo, mensajes de felici@@ tación.
# Había muchos pres@@ os políti@@ cos en la isla de rob@@ b@@ en, pero hay más prisioneros políti@@ cos pal@@ est@@ inos en las cár@@ cel@@ es is@@ ra@@ el@@ í@@ es.
# Solo en la am@@ az@@ on@@ as, perd@@ emos 200@@ 0 árbol@@ es por minuto.
# Yo ya estaba en la ar@@ que@@ ología por natural@@ eza.
# de momento al@@ bert sólo tomó órdenes inferi@@ ores.
# de nuevo otro err@@ or@@ ; 11@@ ...@@ e@@ 6 es correcto.
# los atac@@ antes dispar@@ aron al@@ -@@ may@@ ah más de 20 veces.
# mar@@ tin k@@ ing añ@@ adi@@ ó: definitivamente estamos trabajando juntos.
# No vengan a nuestro congr@@ eso excepto que tengan algo que decir sobre el naci@@ miento de la l@@ una.
# la guerra por las vac@@ as@@ : más de tres sig@@ los de una g@@ esta olvid@@ ada.
# le gusta correr pero, sobre todo, cantar.
# Se supone que tenías que oír al público en todo caso, ya que escu@@ c@@ han el sho@@ w del ser@@ ge@@ ante pe@@ p@@ per.
# Además, alrededor de 500 personas son rel@@ ativ@@ amente reci@@ entes in@@ migr@@ antes rus@@ os.
# Dijo que amis@@ om había estado haciendo un gran trabajo, a pesar de sus re@@ tos de capaci@@ dad.
# Además, la s@@ un@@ s@@ ciencia de dios antici@@ pa nuestras resol@@ u@@ ciones.
# te@@ ac@@ h era uno de los que vinieron para disfrutar de los benefici@@ os de la isla.
# Vi@@ si@@ eron a las familias de los pres@@ os políti@@ cos en y@@ ang@@ ón todos los dom@@ ing@@ os durante este perio@@ do.
# He visto lo que él hac@@ e, y es criminal.
# tiene la responsabili@@ dad, como en un gobierno se@@ cul@@ ar@@ ."
# la carne de lobo que habían comido era probablemente carne humana.
# In@@ vent@@ é mi propio mundo, mi propia realidad.
# a modo de ejemplo, el artículo 18@@ 9 b en el procedi@@ miento de co@@ decisión se convirtió en el artículo 25@@ 1.
# Sin embargo, k@@ enn@@ ed@@ y no puede encontrar a su amigo.
# No volverá a estas tierr@@ as.
# arm@@ stron@@ g y el grupo pasó el resto de la noche bebi@@ endo whisky y discu@@ tiendo lo que había pasado.
# Sin embargo, su nuevo equipo de 25 comis@@ arios se enfr@@ enta a una ruta más dura.
# ella cant@@ ó en el ál@@ bu@@ m indi@@ go gir@@ os a pesar de nuestras difer@@ encias.
# el programa moder@@ ni@@ z@@ a@@ ó el f@@ -@@ 16 en tres eta@@ pas.
# In@@ vi@@ tó su ob@@ edi@@ encia debi@@ da (@@ be@@ fe@@ h@@ l is@@ t be@@ fe@@ h@@ l@@ ) como argu@@ mento en su descar@@ ga.
# Además, ahora cada k está asoci@@ ado a tres coorden@@ adas normal@@ es.
# Jones también dijo que sex pistol@@ s le salvó de una vida de del@@ ito.
# Hay dos@@ : ta@@ i@@ w@@ án y la uni@@ ón eur@@ ope@@ a.
# la pérdida del canal 1 parece ser perman@@ ente.
# ella era la favor@@ ita de la familia hasta que tom@@ ás lleg@@ arás a la espera de la vida.
# Sin embargo, la libertad religi@@ osa en el irán está lejos de ser absolu@@ ta.
# de hecho, la ciudad como institu@@ ción parece haber prosper@@ ado a gre@@ cia durante este perio@@ do.
# in@@ come ine@@ quali@@ ti@@ es th@@ re@@ at@@ en af@@ ri@@ ca.
# él nunca al lado o en contra de g@@ ord@@ on fre@@ em@@ an.
# ¿Quién es capaz de gen@@ oci@@ di@@ o?
# i@@ f y@@ ou ha@@ ve a me@@ e@@ tin@@ g in et@@ hi@@ o@@ pi@@ a, y@@ ou@@ '@@ d b@@ et@@ ter d@@ ou@@ ble ch@@ ec@@ k the ti@@ me (@@ en angl@@ ès@@ -@@ us@@ )@@ .
# Sin embargo, el nombre mala ha sido usado en ir@@ land@@ és durante más de 300 años.
# sin la verdad, es difícil asegur@@ ar la justicia y para hablar de derech@@ os.
# Jim y ber@@ ni reclu@@ taron a los ar@@ tis@@ tas.
# i@@ f the cap fi@@ ts.
# Ya no es el río grande.
# Me am@@ é en j@@ im, pero él era po@@ bre.
# Sin embargo, el gobierno y el sul@@ tan@@ o enten@@ dieron el mensaje.
# (@@ para los sistemas pal@@ o, se sustitu@@ ye 4@@ 80 por 5@@ 7@@ 6@@ .@@ )
# El paci@@ ente no sólo re@@ pi@@ tió palabras que había oído una detrás de la otra.
# el experim@@ ento requiere que usted continú@@ e.
# com@@ parte frecu@@ encia con bar@@ n@@ k@@ anal@@ en.
# al hacer esto, az@@ er@@ bai@@ y@@ án se abri@@ ó aún más hacia eur@@ op@@ a y oc@@ cid@@ ente.
# normal@@ mente los médicos lo hacen durante 20 minutos.
# ofrec@@ e a la@@ w@@ son la posibilidad de trabajar juntos otra vez.
# el at@@ end@@ ance era aproxim@@ adamente 24@@ ,000 (@@ ninguna figura oficial fue registr@@ ada debido a un problema de orden@@ ador@@ )@@ .
# en estos mismos años, m@@ y@@ an@@ mar y ta@@ il@@ an@@ dia perder@@ on el 14@@ % y 2@@ 6@@ % de su bosque natur@@ al, respec@@ tiv@@ amente.
# para hacer algo que significa algo para ellos es la razón por la que g@@ ay@@ na@@ x lo hace todo.
# en mar@@ zo de 199@@ 9 19 personas perdi@@ eron sus trabaj@@ os allí porque menos personas están fu@@ mando.
# S@@ un@@ set@@ s, t@@ w@@ ili@@ gh@@ ts, and ev@@ en@@ ing sk@@ ies (@@ en angl@@ è@@ )@@ .
# las órdenes son destruir@@ lo sobre agu@@ as neutr@@ ales?
# de acuerdo con la resol@@ u@@ ción 9@@ 00 (@@ 199@@ 4@@ )@@ , se cre@@ ó un fondo fi@@ du@@ ci@@ ario voluntar@@ io para contribu@@ ir en este proc@@ eso.
# Hay que destruir un pequeño por@@ centa@@ j@@ e, ind@@ ud@@ ablem@@ ente, en el interior del país.
# También sé que esto es muy bueno para los miles y miles de personas proc@@ ed@@ entes de la ch@@ ina.
# Como el ro@@ jo se centr@@ a tempor@@ almente, parece que está enfr@@ ente.
# También se llama la cum@@ bre inter@@ co@@ re@@ ana 10@@ .@@ 4.
# Hay muchas lec@@ ciones que mar@@ ko tiene que aprend@@ er, si quiere tener éxito.
# ninguna decisión ha estado actu@@ almente hecha sobre la decisión para crear e-@@ k@@ r@@ ona.
# la respuesta final para c es por lo tanto 4@@ 4@@ 5, como en el primer mé@@ todo.
# 100@@ .000 pueden hablar@@ lo activ@@ amente.
# l@@ u z@@ hi@@ : p@@ and@@ as are her th@@ ing.
# Y lo que me sorpren@@ dió de algunos de ellos era su patri@@ o@@ tis@@ mo pol@@ a@@ co.
# 4@@ : este vuelo funciona a través de@@ har@@ ar@@ e.
# w@@ il@@ der@@ s se o@@ pone firm@@ emente al sistema políti@@ co ne@@ er@@ land@@ és en general.
# pronto se hizo evid@@ ente que la banda todavía estaba perdiendo dinero.
# las fu@@ entes discu@@ ten si antes o después del 9@@ 5@@ 5.
# Además, aére@@ o ha empezado su campaña #@@ a@@ eri@@ ere@@ al.
# este proceso ya no es una fuente signific@@ ativa del@@ 1@@ -@@ prop@@ an@@ ol.
# la historia de los super@@ vivi@@ entes de los and@@ as es tal vez una de ellas.
# dirig@@ ido por char@@ las esposa, el audi@@ tor@@ io principal tiene 5@@ 17 asi@@ entos numer@@ ados.
# Esto sería co@@ her@@ ente con un universo físi@@ co infin@@ ito.
# no fue hasta el 2@@ 7 de dici@@ em@@ bre del 200@@ 0 que las últimas familias pudi@@ eron volver.
# la 7@@ a sesión plen@@ aria aprob@@ ó los document@@ os.
# nuestros últimos momentos están cerca, pero son los momentos de nuestra libertad.
# finalmente muestra sentimientos para rod@@ ney.
# las leyes deberían recom@@ pensar a aquellos que las cum@@ pl@@ en y casti@@ gar a aquellos que las des@@ obe@@ dec@@ en.
# por cada una de las horas de 1 a 6 se cal@@ cula la fórmu@@ la.
# el re@@ conocimiento de un nuevo gobierno para otros esta@@ dos puede ser importante para su supervi@@ ven@@ cia a largo plaz@@ o.
# C@@ ata@@ lu@@ ñ@@ a dice suficiente
# un sacer@@ dote declar@@ ó en 16@@ 6@@ 9@@ : durante tres años no se ha re@@ cogido ninguna cose@@ cha.
# ra@@ q@@ q@@ a será un ej@@ emp@@ lo para todo el país.
# p@@ s@@ l@@ v to be la@@ un@@ ch@@ ed ar@@ o@@ un@@ d de abri@@ l 10.
# todas las ocho universi@@ dades de is@@ ra@@ el us@@ an el h@@ eb@@ re@@ o.
# Tim@@ e of err@@ ors, llamado también st@@ re@@ et@@ w@@ i@@ se 199@@ 2.
# los animales son también una parte de este universo eter@@ no.
# diez días después de la primera elección libre y jus@@ ta, se acab@@ arían todas las medi@@ das.
# los descen@@ dientes de estos tres identific@@ ados como blan@@ cos.
# el lobo debería esperar hasta 19@@ 5@@ 1 para tener otra oportunidad de gobern@@ ar.
# Luego se re@@ pi@@ te om ah hu@@ m tres vegades.
# jo@@ h@@ n ros@@ s no vio las is@@ las be@@ au@@ fort.
# r@@ or recep@@ tor t@@ y@@ ros@@ ine kin@@ ases@@ : or@@ ph@@ ans no more.
# hol@@ y land us@@ a, un par@@ que similar a con@@ eci@@ do.
# (@@ char@@ las e. mi@@ x fue el comi@@ sion@@ ado que firm@@ ó por el gobierno feder@@ al@@ .@@ )
# la muerte de ny@@ er@@ ere, el 14 de oc@@ tu@@ bre de 199@@ 9, todavía es con@@ memor@@ ado an@@ u@@ almente.
# También registr@@ an la derro@@ ta de los ár@@ ab@@ es en dos lugar@@ es.
# Ten@@ ían que reun@@ irse con sus escol@@ tas del z@@ g 26 sobre el can@@ al.
# los judí@@ os de roman@@ ía nunca olvid@@ aremos estos hechos de importan@@ cia hist@@ ó@@ ri@@ ca.
# b@@ et@@ sis le respon@@ di@@ ó, ¿@@ cree usted que soy un perro o un animal para transfer@@ ir@@ me?
# form@@ aba parte de su términ@@ o primi@@ geni@@ o.
# Así que, tenía tres ac@@ tos, tres personas.
# a la medi@@ anoche 4@@ 7 ci@@ cli@@ s@@ tas habían lleg@@ ado, algunos de ellos en auto@@ bus@@ es.
# ö@@ tz@@ i, elu@@ om@@ o ven@@ dido d@@ al g@@ hi@@ ac@@ cio (@@ en it@@ -@@ it@@ )@@ .
# de esta manera, no saben por quién jugar@@ án hasta minutos antes.
# esta nueva ent@@ idad tomó el proyecto cr@@ ay@@ -@@ 3 con ellos.
# se acab@@ aron también las medi@@ das impu@@ estas en otras resol@@ u@@ ciones.
# nar@@ ra@@ tiva ahora sí que la he hecho buen@@ a@@ !@@ .
# ¿@@ I@@ l papá?
# Ru@@ si@@ a: suc@@ es@@ or confir@@ me@@ d.
# los mismos números para acon@@ teci@@ mientos directamente relacion@@ ados con los aeropuer@@ tos son 5 res@@ p.
# Este es el único caso documen@@ tado de una traduc@@ ción dob@@ le, simul@@ t@@ án@@ ea.
# los pueblo también tenía uno o más ki@@ va, que u@@ sab@@ an como cámaras religi@@ osas.
# Me desarroll@@ ó, le@@ ía conmigo.
# No tiene ningún gobern@@ ador en ni@@ ger@@ ia hoy día.
# las vari@@ aciones están disponi@@ bles para ow@@ l y ow@@ l@@ 2.
# Es el único torn@@ eo nunca organiz@@ ado para con@@ mem@@ orar un competi@@ dor.
# a diferencia de casi todos los prim@@ ados les encanta el agua.
# (@@ bas@@ ado en la edi@@ ción de 200@@ 4, no todavía en líne@@ a@@ )
# tenían uni@@ formes diferentes y preten@@ dí@@ an compe@@ tir por primera vez como represent@@ antes de su propio país.
# las personas piensan de mí como el tipo de the practi@@ ce@@ ...
# sus reci@@ tales constitu@@ y@@ en una lección ejempl@@ ar.
# durante estas dos confer@@ encias nueva guin@@ ea fue discuti@@ da por primera vez.
# ¿Por qué decir no al inc@@ esto?
# todos los dioses tenían un poder.
# Aunque no depende de él@@ /@@ ella para hacer leyes (@@ sólo para prom@@ ul@@ gar y hacer edic@@ tos@@ )@@ , el presidente es el líder del partido gan@@ ador.
# Sin embargo, la alem@@ ana mer@@ idi@@ on@@ al muestra por sí misma algunos desarrol@@ los in@@ depen@@ dientes.
# an@@ go@@ la y ni@@ ger@@ ia son ej@@ emp@@ los de estos tipos de mercad@@ os.
# r@@ w@@ anda : k@@ ing jam@@ es j@@ ets of@@ f to eur@@ op@@ e f@@ or the fir@@ s@@ t ti@@ me.
# Esto es todo lo que nuestra cultura representa en defin@@ i@@ tiva.
# El pueblo fue a decirle a mo@@ is@@ és@@ :
# Por lo tanto, se usa 3 d@@ of@@ , porque sólo hay 3 gr@@ ados de movi@@ miento.
# desde que está aquí, hemos visto fú@@ t@@ bol de otro planeta.
# un sistema de seguridad es tan seguro como su secreto.
# todas las cre@@ encias cultur@@ ales hacia el m@@ s@@ m son neg@@ ativ@@ as.
# 198@@ 9 la mu@@ la viej@@ a, em@@ puri@@ as.
# Casi un ter@@ cio de ellos estudi@@ ó en program@@ as relacion@@ ados con la econom@@ ía y negocios.
# Estoy contento a In@@ glaterra y quiero demostrar a todo el mundo que realmente puedo jugar a fú@@ tbol@@ .
# lo también puede considerar su ley trib@@ al como su soñ@@ ar.
# poco después llegó una inspec@@ ción fiscal no plan@@ ific@@ ada en las ofic@@ inas de ayuda jus@@ ta.
# ¿Es un primero hacia ton@@ y como una especie de ment@@ or?
# la desnu@@ tr@@ ición en los dos primeros años es irre@@ versi@@ ble.
# Esto puede ser importante para de@@ terminar si eur@@ op@@ a podría ser habita@@ ble.
# desde la publi@@ c@@ ación de la primera edi@@ ción de 5@@ .00@@ 0, más@@ ...@@ )
# Bus@@ h a menudo pregunta@@ b@@ a: ¿A@@ y@@ ud@@ ará a ganar una guerr@@ a; esta guerra?
# 16@@ 8@@ )@@ , pero parece que es un error.
# tanto tur@@ qu@@ ía como fran@@ ça conden@@ aron a los asesinatos de las tres mujeres.
# ro@@ pero morir (@@ primero a la izquierda de la mes@@ a@@ ) 18@@ .
# estos hombres vienen a ven@@ cer o morir.
# libros de w@@ ay@@ ne mill@@ er@@ : a bab@@ y@@ 's fir@@ s@@ t y@@ e@@ ar.
# k@@ ab@@ era dijo que le gustaría hacer una co@@ medi@@ a.
# nob@@ el f@@ or y@@ ou@@ : to@@ p 10 nob@@ el s@@ nu@@ b@@ s.
# El cuerpo del perro es ro@@ jo, lo que significa también un día de fuego.
# i@@ i - determin@@ ación de gru@@ pos próxim@@ os
# el enseñ@@ ador de pi@@ sos que odi@@ aba los mi@@ mos.
# El nombre o@@ pen@@ /@@ cl@@ os@@ ed princi@@ ple se usó de dos formas.
# en un nou prò@@ le@@ g per a l'@@ edi@@ ción de 200@@ 4 de the oc@@ cul@@ t ro@@ ot@@ s...
# en@@ ver ho@@ x@@ ha hizo esto como lo hizo hi@@ t@@ ler.
# Sin embargo, is@@ ra@@ el y sí@@ ria se mantu@@ vieron en estado de guerra durante todo este perio@@ do (@@ y, de hecho, hasta la actu@@ al@@ idad@@ )@@ .
# (@@ 12 divi@@ dido por 0@@ ,@@ 25 hor@@ as@@ )@@ .
# por c@@ rom@@ ow@@ ell, el ejército era ahora el instru@@ mento elegido por dios.
# Como men@@ dic@@ antes, estaban acostumbr@@ ados a viaj@@ ar.
# q@@ i y le oper@@ an juntos en mu@@ tua depend@@ encia.
# Como hizo a l@@ on@@ dr@@ es, empieza enseñ@@ ándol@@ es el respeto por los demás.
# Al menos una prisión falta de electrici@@ dad.
# algunas mujeres elig@@ ieron cas@@ arse con pir@@ ata@@ s.
# 1 sep@@ tiem@@ bre 1@@ th and terroris@@ m fa@@ q@@ .
# Segui@@ ó pal@@ o@@ u, ir@@ a@@ ís.
# ¡@@ Realmente intent@@ en y sient@@ en amor@@ ; realmente den amor a través de eso!
# se llevó a cabo una segunda audi@@ encia cuatro años más tarde (@@ 8@@ 9 f. su@@ p@@ p.
# el che@@ ico solo tenía 2@@ 50 o@@ ve@@ jas.
# un equipo de hombres y mujeres constru@@ yó la es@@ cultura en eg@@ i@@ p@@ to.
# también dijo que el sol era la más grande de las estrell@@ as.
# También ha publi@@ cado un libr@@ o, g@@ et@@ tin@@ g w@@ il@@ d sex fr@@ om y@@ ou@@ r conserv@@ ati@@ ve w@@ om@@ an, en 200@@ 8.
# entre 197@@ 0 y 200@@ 1, el parl@@ amento b@@ el@@ ga aprob@@ ó cinco re@@ formas constitu@@ cion@@ ales suc@@ esi@@ vas.
# Estos manif@@ est@@ antes sólo quieren una asoci@@ ación más est@@ rec@@ ha con la uni@@ ón eur@@ ope@@ a.
# Sin embargo, el 9@@ 2@@ ,@@ 5 por ciento del material de armas quími@@ cas elimin@@ ado o destru@@ ido es un progr@@ eso signific@@ ativo.
# no estoy contento sobre su opinión (@@ de t@@ ø@@ f@@ ting@@ )@@ .
# cinco libros con aproxim@@ adamente 90 págin@@ as también sal@@ ieron al br@@ asi@@ l.
# En 20@@ 15@@ , los tres paí@@ ses también han ab@@ ol@@ ido los permis@@ os de trabajo para los ciudadanos de los tres paí@@ ses.
# Estamos fascin@@ ados por todas las formas de desapar@@ ici@@ ón, de nuestra desapar@@ ici@@ ón.
# lo que es no@@ table sobre todo este proceso es que fue conseguido con un mínim@@ o de enmi@@ end@@ as leg@@ is@@ la@@ tiv@@ as.
# ca@@ is@@ -@@ do@@ -@@ so@@ dré tiene sal@@ aman@@ sa.
# se localiz@@ a en la cara ocul@@ ta de la lun@@ a, por lo que no es visi@@ ble desde la tierra.
# Él las mir@@ ará y tomó la copa de lech@@ e.
# incluso los otros no-@@ cristi@@ anos empez@@ aron a tomar nota de la nueva religi@@ ón.
# Es una bella colec@@ ción de 3@@ 4@@ 4 or@@ aciones.
# j@@ im se siente tras@@ torno y traicion@@ ado después de 15 años de lealtad a la empresa.
# (@@ este es el mismo material llamado pl@@ exig@@ l@@ ás y lu@@ ci@@ te@@ )@@ .
# Dob@@ lar una memoria de 10@@ 24 palabras produc@@ e otra memoria pequeña.
# después de 6 f@@ 4, en una de las líne@@ as principal@@ es, 6@@ ...
# aten@@ eo de n@@ á@@ uc@@ ra@@ ti@@ os.
# el sector público también ha adop@@ tado u@@ bun@@ tu.
# John h@@ enr@@ y quiere que sean mitad chico y mitad chica.
# 3@@ 1 es un identific@@ ador ar@@ bi@@ tr@@ ario.
# en dici@@ em@@ bre de 199@@ 8, el gobierno y uni@@ ta estaban de nuevo en estado de guerra.
# No, nuestro destino es uno.
# los problemas pueden apar@@ ecer cuando diver@@ sas fu@@ entes ofrec@@ en el mismo paqu@@ e@@ te@@ (@@ s@@ )@@ .
# w@@ eb@@ er quería un creci@@ miento econ@@ ó@@ mico ili@@ mi@@ tado.
# Sin embargo, algunas autor@@ idades modern@@ as prefi@@ eren situ@@ ar at@@ ar@@ ot@@ h en otros lugar@@ es.
# Sólo el gran@@ ada lo viene claro (@@ en cast@@ ell@@ ano@@ )@@ .
# En consecu@@ encia, bus@@ he@@ h@@ r sería comi@@ sion@@ ado a principi@@ os de 200@@ 9, después de cinco retras@@ os de dos años cada uno.
# a nuestro equi@@ po, el capitán es el general i@@ ke.
# cada dos años cos@@ par pide una as@@ am@@ bl@@ ea general (@@ también llamada as@@ am@@ bl@@ ea científic@@ a@@ )@@ .
# otros gru@@ pos g@@ abi@@ el@@ ino han hecho lo mismo.
# ¡No más mis am@@ éri@@ ca!
# ella está de acuerdo (@@ no@@ w y había e@@ ver@@ y@@ th@@ ing@@ )@@ .
# por 16@@ 8@@ 4 los esp@@ añ@@ ol@@ es y los indi@@ os habían abandon@@ ado las seis mi@@ siones.
# Ahora es hora de disfrutar de nuestra victor@@ ia.
# igual que con la ag@@ ente, esta financi@@ ación fue amor@@ ti@@ z@@ ado por petróle@@ o bol@@ i@@ vi@@ ano.
# Mi propia cultura me in@@ hibi@@ a.
# archi@@ ver@@ os sin fronter@@ as, una apu@@ esta por la solid@@ ar@@ idad archi@@ ví@@ sti@@ ca inter@@ nacional.
# es tan rica y antigua como la de la ch@@ ina y la de mes@@ o@@ po@@ ta@@ mi@@ a.
# se espera que el total de re@@ torno de datos científi@@ cos de la superfici@@ e sea 1.@@ 4 g@@ bi@@ ts.
# ella usa la misma comunic@@ ación direc@@ ta y gen@@ u@@ ina para motiv@@ ar a su equipo.
# en abri@@ l de 20@@ 10 dijo que cu@@ ba estaba en cri@@ sis.
# 1.@@ 13 los hechos en el espacio lógic@@ o son el mundo.
# ¡@@ Había cientos por minuto justo por debajo de nosotros, realmente especta@@ cul@@ ar!
# q@@ : ¿crees que es posible crear nuevos person@@ ajes que pueden tener el mismo impac@@ to?
# el propósito final es acer@@ car pro@@ gres@@ i@@ vam@@ ente a los paí@@ ses soci@@ os medi@@ terr@@ áne@@ os al mec@@ an@@ ismo eur@@ ope@@ o de protección civi@@ l.
# ¡S@@ ig@@ an trabajando para él... oh, querido salv@@ ador!
# Todas las pro@@ pu@@ estas y re@@ formas posteri@@ ores de la lengua bi@@ el@@ or@@ us@@ sa se han bas@@ ado en su codific@@ ación.
# de las 100 econom@@ ías más grandes de la tierra ahora, 5@@ 1 son corpor@@ aciones.
# la más importante de los cuales es la revolu@@ ción ha@@ i@@ ti@@ ana.
# com@@ ing son@@ id@@ or@@ : har@@ r@@ y pot@@ ter chan@@ ges re@@ le@@ ase date.
# Cuando estamos juntos, hablamos mucho sobre liter@@ atura.
# defin@@ ición de ssi@@ d (@@ ingl@@ és@@ )
# la de@@ vas@@ tación de co@@ pen@@ hagu@@ e, pero, proporcion@@ ará nuevas oportun@@ idades.
# cuando el proyecto terminó en 199@@ 3, se había re@@ copi@@ lado información detall@@ ada de 2@@ .@@ 40@@ 3 casos.
# ellos fueron conduci@@ dos en el campo cercan@@ o tan juntos que se to@@ cab@@ an entre sí.
# 9 (@@ il@@ ustr@@ acion@@ es@@ )
# "@@ go@@ d on@@ ly k@@ no@@ w@@ s" es una canción muy especial.
# Como consecu@@ encia, s@@ pa@@ ak pidió dos meses más para preparar su informe final.
# mar@@ tin tuvo varios meses de retras@@ o en el tercer libr@@ o, tormenta de espad@@ as.
# thi@@ s mo@@ ve is l@@ on@@ g o@@ ver@@ du@@ e - ind@@ ustr@@ y respon@@ ds to e@@ 3 go@@ ing publi@@ c (@@ en en@@ )@@ .
# Sin embargo, algunos creen que hay un tercer tipo de gr@@ b@@ s.
# Er@@ a, de acuerdo con el au@@ tor ste@@ v tur@@ ner, un matrimonio hecho en el ciel@@ o...
# ¿El retir@@ o del orden de sacrifici@@ o significa menos viol@@ encia?
# Hu@@ bo, sin embargo, poca actividad en el dis@@ tri@@ to hot@@ el@@ ero hasta el mes siguiente.
# Si nuestro Q@@ i está claro y equi@@ libr@@ ado, entonces actu@@ aremos de una manera perfectamente mor@@ al.
# por ejemplo, este mensaj@@ e: y había siendo vía at t@@ w@@ o o@@ '@@ cl@@ ock fo@@ ur lar@@ ge ham@@ s and t@@ w@@ o s@@ mal@@ l ham@@ s (@@ '@@ he enviat a les dues de la mad@@ rug@@ ada quatre per@@ ni@@ ls grans i dos de peti@@ t@@ s'@@ )@@ , indic@@ aba que cuatro adul@@ tos y dos niños habían sido envi@@ ados con tren de h@@ arris@@ bur@@ go (@@ pen@@ sil@@ v@@ ani@@ a@@ ) hasta fil@@ adel@@ fi@@ a.
# es presidente elec@@ to de ins@@ ar.
# la quin@@ ta se refiere a cómo las cosas empez@@ aron.
# (@@ el apar@@ th@@ ei@@ d no terminó hasta más de 4 años después de que cu@@ ba abandon@@ ase an@@ gol@@ a@@ )@@ .
# E@@ gi@@ p@@ to contribu@@ ye con 4@@ 8@@ 1 bar@@ cos.
# ella afir@@ m@@ ó que había hecho trabajo mínim@@ o para el ban@@ co.
# aqu@@ eras mon@@ tan@@ has@@ ; aqu@@ eras mon@@ tan@@ h@@ es@@ ; aqu@@ el@@ e@@ i mon@@ tan@@ has@@ ; aqu@@ el@@ i mon@@ tan@@ has@@ ) o la fuente de nim@@ es (@@ v@@ ar.
# D@@ entr@@ o: hace 20 años que tengo 20 años, 198@@ 4.
# 199@@ 8@@ : el hombre, la hem@@ bra y el hambre (@@ no@@ vel@@ a@@ )@@ .
# pronto se convier@@ ten en no@@ tor@@ ios delincu@@ entes.
# en este pun@@ to, él y hol@@ den coincid@@ en.
# el servi@@ ce pac@@ k 5, por ejemplo, fi@@ ja las cuesti@@ ones relacion@@ adas con el problema del año 200@@ 0.
# se afir@@ ma que ha sido de unos 18 a 20 años sola en la isla.
# se ama que habrían necesita@@ do alrededor de 20 hombres adi@@ cion@@ ales para este man@@ teni@@ miento.
# ni el emperador ni ninguno de los barcos de@@ volvió a maldi@@ to.
# 3@@ 9@@ : todas las activi@@ dades y propag@@ anda comun@@ istas están prohibi@@ das.
# ¿Cuándo vuelven de nuevo a las palabras que ya han visto?
# arte firm@@ ó con lec@@ l@@ er@@ co la semana siguiente.
# en 200@@ 3 los pal@@ est@@ inos dejaron de usar la carretera principal por completo.
# ella, él y un cafe@@ to rom@@ anti@@ co, bar@@ cel@@ ona 19@@ 2@@ 8.
# w@@ h@@ en y u@@ se a w@@ ord@@ ..
# Sin embargo, hasta 200@@ 8 todos los aviones están siendo registr@@ ados en s@@ ã@@ o tomé e prínci@@ pe.
# el informe franc@@ és de 199@@ 8 no hizo ninguna determin@@ ación entre las dos teor@@ ías domin@@ antes.
# Fue una de las 3@@ 9 mujeres eleg@@ idas o des@@ ign@@ adas en el parl@@ amento ese año, en compar@@ ación con 4@@ 1 hombres.
# Intent@@ ó responder dos pregun@@ tas@@ : ¿Hay otras plane@@ tas habita@@ das?
# car@@ mac@@ k había sido un cliente tan re@@ gu@@ lar que todavía le cobr@@ an preci@@ os de 199@@ 5.
# E@@ qui era la única política entre ellas.
# el parl@@ amento debe ser un puesto de trabajo, no de conflic@@ to.
# ¡No es graci@@ oso y pago otra persona para hacer las or@@ qu@@ estacion@@ es!
# algunas organiz@@ aciones e individu@@ os incluso lo llaman epi@@ dem@@ ia de au@@ tis@@ mo.
# Hoy no es as@@ í@@ : hay que haber hecho la dig@@ esti@@ ón.
# También hab@@ ía, al parec@@ er, una jer@@ ar@@ qu@@ ía entre los mismos gobern@@ adores.
# Jon@@ ah@@ : in pur@@ su@@ it of the do@@ ve.
# fr@@ om@@ '@@ monst@@ er@@ s@@ ' ton@@ o moder@@ no medic@@ al milagr@@ os, 21 de jun@@ io de 200@@ 8.
# Nadie necesita un piloto que no puede controlar su propio ev@@ a..
# un re@@ trato completo de j@@ es@@ ús nunca podría bas@@ arse en tan pocos d@@ atos.
# en la elección entre oth@@ man y al@@ i para de@@ terminar quién será el suc@@ es@@ or para el profe@@ ta, vo@@ ta@@ ban@@ !
# envió a manu@@ el y a se@@ at@@ on con esta misión.
# Sin embargo, el informe del departamento de estado de tus ojos es grav@@ emente in@@ completo.
# Hubo re@@ per@@ cu@@ siones inter@@ nacion@@ ales en las acciones de Jack@@ son.
# 1@@ 7. d@@ 6 hubiera sido mejor, aunque la posición de las negr@@ as todavía es superior después de 17@@ ....
# i@@ ris@@ h set dan@@ ce@@ : s@@ quar@@ e d@@ ance con asoci@@ aciones reg@@ ion@@ ales fuer@@ tes.
# us@@ an la montaña como su símbol@@ o oficial.
# a veces, bri@@ lla en la noche como el sol, pero sólo por una hora o algo así.
# antes de que bo@@ w@@ ie lleg@@ ara, la gente no quería muchos cambi@@ os.
# Dios es ahora una reg@@ la, y la religi@@ ón sería más fer@@ vi@@ ente y emocion@@ al.
# cada año hasta el 1@@ 10@@ 5 lanz@@ ó sus fuerzas en camp@@ añas en pal@@ est@@ ina e institu@@ yó re@@ formas para for@@ tal@@ ecer la po@@ tencia militar eg@@ i@@ p@@ cia.
# También hay una dis@@ puta sobre la cond@@ ena im@@ puesta bajo el código militar alem@@ án.
# Espero sincer@@ amente que durante su vida seamos capaces de rell@@ en@@ ar una econom@@ ía verde glob@@ al.
# los hermanos divi@@ dieron sus tierras en 12@@ 5@@ 5 en contra de la ley.
# en este po@@ em@@ a, la primera rosa es el nombre de una persona.
# ambos dese@@ an un futuro mejor para sus hijos.
# a partir de 200@@ 5, no se permit@@ ía la cir@@ cul@@ ación de coches pal@@ est@@ inos priv@@ ados, aunque el trans@@ porte público todavía estaba permiti@@ do.
# El consejo de gobierno de las fuerzas arm@@ adas había diseñ@@ ado un real@@ ista programa econ@@ ó@@ mico de dos años.
# ha@@ p@@ p@@ y bir@@ th@@ d@@ ay@@ : th@@ e@@ '@@ sh@@ ock@@ ing and in@@ mor@@ al@@ ' bi@@ kin@@ i hi@@ ts 60.
# al@@ -@@ q@@ ai@@ da ha llevado a cabo oper@@ aciones y reclu@@ tado miembros en el af@@ ri@@ ca.
# el doctor meti@@ eron también sufri@@ ó una sever@@ a tortur@@ a.
# Como resul@@ tado, las noticias tien@@ den a ser tradu@@ ci@@ das superfici@@ almente al lux@@ em@@ bur@@ gu@@ és.
# Sin embargo, este procedi@@ miento es princip@@ almente fi@@ able para ad@@ cs.
# el informe oficial no dice cómo av@@ anza el can@@ ad@@ ien@@ o en la segunda ron@@ da.
# se decidió que se ejecu@@ taría una nueva política de asi@@ mil@@ ación.
# desde ese momento, ey@@ ü@@ p se convirtió en una especie de lugar sagr@@ ado.
# la re@@ patri@@ ación de los refugi@@ ados tenía que ser mejor coordin@@ ada.
# la prohibi@@ ción total de armas fue rechaz@@ ada por br@@ asi@@ l y rus@@ ía.
# ...
# el resto del día resul@@ tó un desastre caus@@ ado por las pobres comunic@@ aciones entre bu@@ ll@@ er y sus comand@@ antes.
# Por lo tanto, ya no hay una base econ@@ ó@@ mica para mantener el sistema le@@ ica r en el programa de produc@@ ción de le@@ ica.
# 19@@ 0@@ 7, por primera vez, dos indi@@ os ser@@ ían nombr@@ ados miembros del consejo.
# la administr@@ ación de veter@@ anos también adop@@ tó una versión liger@@ amente modific@@ ada del médico 20@@ 3.
# se establ@@ e@@ cieron cur@@ sos de form@@ ación par@@ am@@ ili@@ tar.
# este modelo pro@@ puesto fue criti@@ cado con razón.
# gim@@ bo 2@@ .@@ 8 fue lanz@@ ado el 3 de ma@@ yo de 20@@ 12 con varias re@@ visiones en la inter@@ fa@@ z de usu@@ ario.
# the cre@@ atur@@ es es van convertir de fac@@ to en su única banda.
# Pu@@ si@@ eron a lo@@ u@@ is a unos qu@@ ince pies en la esqu@@ ina, mirando a todos trist@@ os.
# El mu@@ se@@ o recor@@ re la historia de la produc@@ ción de cerveza a los últimos 6@@ .000 años, especialmente los desarrol@@ los más reci@@ entes en lux@@ em@@ bur@@ go.
# An@@ ab@@ ita también re@@ ú@@ ne una pobl@@ ación signific@@ ativa de pal@@ est@@ inos origin@@ arios de g@@ az@@ a que no están clasific@@ ados entre las famili@@ as.
# en el tercer di@@ agr@@ am@@ a, las blanc@@ as gan@@ an fácil@@ mente.
# marcha de la biblioteca para llevar a mari@@ an a la cama.
# dos nuevas fran@@ quí@@ ci@@ es - the cre@@ w y the di@@ visi@@ on@@ - también se anunci@@ aron.
# los esta@@ dos un@@ idos y rus@@ ía no con@@ sigui@@ eron acer@@ car pos@@ tur@@ as en la crisis de uc@@ ran@@ ia, después de seis horas de convers@@ aciones a l@@ on@@ dr@@ es.
# de hecho, su padre, antes de morir, tuvo tiempo de enseñ@@ arle un lanz@@ amiento má@@ gi@@ co.
# du@@ g@@ dale ent@@ eros i'm a cel@@ ebri@@ ty jun@@ g@@ le (@@ en@@ -@@ g@@ b@@ )@@ .
# la ley del ur@@ u@@ gu@@ ay contra la viol@@ encia dom@@ é@@ sti@@ ca es la ley no 17@@ .@@ 5@@ 14@@ , prom@@ ul@@ gada en 200@@ 2.
# foto del teni@@ ente w@@ ay@@ ne mill@@ er.
# k@@ on@@ ra@@ d aden@@ au@@ er afir@@ mó@@ : el términ@@ o protec@@ tor@@ ado es demasiado amable.
# sólo x@@ avi a@@ prueba el primer examen (@@ en cast@@ ell@@ ano@@ )@@ .
# a través de varios program@@ as de inter@@ cambi@@ o, in@@ w@@ ent también ofre@@ ció la ex@@ posición inter@@ nacional para los jóvenes alem@@ anes.
# mencion@@ ó a la princesa k@@ insk@@ y que estaba oblig@@ ado a dar apoyo completamente a un hermano enfermo desafortun@@ ado y a toda su familia.
# A continu@@ ación, hay una entrada típic@@ a del su@@ pl@@ em@@ ento revis@@ ad@@ o: x C@@ if@@ ra@@ x@@ y, to be ch@@ ang@@ ed in@@ to a co@@ w, s@@ .@@ f@@ r.
# también se comprometi@@ ó a comb@@ a@@ tir el extre@@ mismo muy pronto.
# Por lo tanto, sería la fuerza de reemplaz@@ ar otra víctima en lugar de la primera.
# desde abri@@ l hasta ma@@ yo de 200@@ 7, el tribunal constitu@@ cional revis@@ ó 10@@ 1 leyes y de@@ cre@@ tos, se decidió que eran constitu@@ cion@@ ales.
# También revel@@ ó como los patri@@ o@@ tas tem@@ ían en camp@@ b@@ ello como comandante de habilidad grande.
# los tres son de k@@ arl@@ stad.
# fun@@ d@@ ó la comi@@ sión para personas desapareci@@ das y víctimas de la viol@@ encia (@@ k@@ on@@ tras@@ )@@ .
# el artículo 3 esti@@ pul@@ aba que las fronter@@ as entre pol@@ onia y li@@ tu@@ án@@ ea ser@@ ían establ@@ eci@@ das por estos esta@@ dos.
# has@@ k@@ ell con@@ cur@@ r@@ ente am@@ pl@@ ía has@@ k@@ ell@@ 9@@ 8 con con@@ cur@@ ren@@ cia expl@@ í@@ cita.
# Cuando se discu@@ ten, siempre es de manera neg@@ ativ@@ a, de acuerdo con la moral tradi@@ cional is@@ lá@@ mica.
# Dar@@ w@@ is@@ h declar@@ ó pos@@ terior@@ ment@@ e: siempre di la culpa a is@@ ra@@ el por la muerte de mi padre, porque eso era lo que me enseñ@@ aron.
# Además, los incid@@ entes ocurri@@ dos en 19@@ 40 (@@ la amenaza de encar@@ cel@@ amiento en un campo de concentr@@ ación@@ ) habían tenido un efecto des@@ favor@@ able.
# Sin embargo, estos val@@ ores ser@@ ían re@@ orden@@ ados en importan@@ cia y situ@@ ados en el con@@ tex@@ to de un estric@@ to mon@@ ote@@ í@@ s@@ mo.
# la entrada rep@@ ent@@ ina de jun@@ i@@ or inter@@ rum@@ pe la cerem@@ oni@@ a, y nadie lo salud@@ a.
# Esta vez, el voto a b@@ ad@@ en (@@ del sur@@ ) fue el 8@@ 1@@ % en favor del esta@@ tu qu@@ o.
# el segundo habla del compromis@@ o religi@@ oso de un comerci@@ ante.
# desde el punto de vista artí@@ sti@@ co no lamento que la cámara de la as@@ am@@ bl@@ ea se incendi@@ ara, yo esperaba construir una mejor.
# Lu@@ ego, se plan@@ ific@@ aron dos misi@@ ones tripul@@ adas en el primer laboratorio espacial ch@@ ino.
# dice a d@@ avi@@ s que se pondrá en contacto con él más tarde sobre el pag@@ o.
# Por un lado, tenemos intu@@ i@@ cion@@ es@@ ; del otro, hechos científi@@ cos.
# algunos cat@@ óli@@ cos críti@@ cos de los naz@@ is pronto elig@@ ieron em@@ igr@@ ar.
# la reacción s@@ n@@ 1 es posible, pero muy des@@ favor@@ able.
# una segunda líne@@ a, la línea b, con una orien@@ tación del nor@@ este hacia el sur@@ o@@ este, está pre@@ vista para el 20@@ 20.
# más tarde, en los pas@@ os de un avión priv@@ ado, sim@@ on pasa a d@@ avi@@ s la ven@@ us.
# el f@@ esti@@ val abri@@ ó con un americ@@ ano a par@@ izo de vin@@ c@@ ente min@@ n@@ elle.
# mas@@ ter@@ car@@ d carga a los tu@@ ris@@ tas no eur@@ ope@@ os más que los clientes usando tarje@@ tas emi@@ ti@@ das a eur@@ op@@ a.
# igual que él@@ ul@@ , fran@@ k@@ lin afir@@ ma que los mé@@ todos tecn@@ ológi@@ cos domin@@ an el mundo moder@@ no.
# fl@@ inc@@ k fue in@@ capaz de terminar más que los boc@@ et@@ os.
# Sin embargo, se espera que estos sec@@ tores se ampli@@ en en más de un 10@@ % al año debido al au@@ mento de la produc@@ ción de carb@@ ón y gas.
# la téc@@ nica también está asoci@@ ada con el mel@@ o@@ dr@@ ama.
# a través de él y otros como él, nunca volveré a la libertad de descans@@ o en el domin@@ io de unos po@@ cos.
# por raz@@ ones desconoci@@ das u@@ sab@@ a el nombre de le@@ on@@ ard elli@@ ot.
# horas después estas demand@@ as fueron redu@@ ci@@ das a 3@@ 4, pero meses después el informe volverá a analiz@@ arse y se redu@@ jo a 2@@ 7 victor@@ ias confir@@ mad@@ as.
# ciudad sin nombre, po@@ es@@ ía, 199@@ 7.
# los plane@@ tas están también asoci@@ ados, especialmente en la trad@@ ición ch@@ ina, con las fuerzas bási@@ cas de la natural@@ eza.
# mientras que tres personas habl@@ aban la lengua en 200@@ 6, el último hablando flu@@ ente murió en 200@@ 8.
# fran@@ ça también acep@@ tó la pr@@ ag@@ má@@ tica san@@ ción en el tratado de vien@@ a.
# 10.000 lo hablan flu@@ id@@ amente.
# Un millón y medio de judí@@ os fueron asesin@@ ados a aus@@ ch@@ w@@ itz@@ .
# en el proc@@ eso, captur@@ aba las pos@@ esi@@ ones y familias de muchos de los seguid@@ ores de has@@ an.
# hizo varios viaj@@ es entre eur@@ op@@ a y am@@ éri@@ ca sobre estos como super@@ cargo responsable de todas las compr@@ as y ven@@ tas de bien@@ es.
# En la actu@@ alidad mar@@ al está haciendo campaña para que las mujeres ir@@ an@@ í@@ es puedan obtener permis@@ os de conducir y li@@ cen@@ cia para mon@@ tar mot@@ os.
# Fue publi@@ cado en y@@ ou@@ tu@@ be, y enviado como un d@@ v@@ d con todos los miembros del parl@@ amento.
# ma@@ x afir@@ ma que cant@@ arían por a@@ ustri@@ a, pero el capitán señ@@ ala que austr@@ ia ya no existe.
# James dob@@ ie, el histori@@ ador y el autor@@ , y su familia vivi@@ eron aquí desde 18@@ 3@@ 6.
# Todos estos fac@@ tores juntos han hecho que sea extremadamente difícil distin@@ gu@@ ir entre lo que constitu@@ ye una lengua o un di@@ al@@ ec@@ to a mes@@ o@@ am@@ éri@@ ca.
# los principi@@ os conven@@ idos para ra@@ f@@ ah esti@@ pul@@ an que ra@@ f@@ ah también se utiliz@@ ará para la ex@@ porta@@ ción de mer@@ can@@ c@@ ías a eg@@ p@@ to.
# wor@@ l@@ d pre@@ mier@@ e: ge@@ or@@ ge clo@@ on@@ ey w@@ ants a h@@ oll@@ y@@ wood fix@@ er (@@ en en@@ )@@ .
# el primer objetivo era proteger a los soldad@@ os, pero fue ampli@@ amente adop@@ tado como un dispositivo de salu@@ d pública.
# durante las prim@@ eras dé@@ cad@@ as de la exist@@ encia de k@@ ir@@ una, ninguna carretera la conec@@ tó hacia el resto del mundo.
# Él y su mujer murieron de neu@@ mon@@ ía con sólo tres días de diferencia.
# consider@@ amos que el acceso abierto de los medi@@ os de comunic@@ ación a los candid@@ atos políti@@ cos es cruci@@ al en este proc@@ eso.
# En cuanto a la di@@ á@@ s@@ por@@ a s@@ ér@@ bi@@ a, las manif@@ esta@@ ciones dur@@ aron solo 7@@ 8 días en tor@@ on@@ to.
# el cán@@ tico de los cán@@ ti@@ cos en los sig@@ los che@@ i y chi@@ i@@ i@@ : la lec@@ tura de clara de hu@@ eso.
# la intención no era construir el mayor aeropuer@@ to de eur@@ op@@ a, sino construir el aeropuer@@ to favor@@ ito de los pasaj@@ eros en trá@@ fico.
# fis@@ ch@@ er había tenido bastante razón en su rab@@ ia.
# la deci@@ mo@@ tercera edi@@ ción no se jug@@ ó por raz@@ ones supersti@@ ci@@ osas.
# entonces le dimos un polvo negr@@ o, y lo pusi@@ mos en la cama.
# Sin embargo, este comerci@@ o ang@@ lo@@ -@@ hol@@ and@@ és sólo constitu@@ yó una pequeña frac@@ ción del total de las corri@@ entes comerci@@ ales hol@@ an@@ des@@ es.
# afir@@ mar@@ on que un incre@@ mento de fr@@ am@@ em@@ ate a 70 h@@ z sería posible a través del uso de un puerto h@@ d@@ mi 1.@@ 4.
# ol@@ s@@ son conseguir@@ on escapar del país (@@ probablemente con la ayuda de su compañ@@ er@@ a@@ )@@ .
# las negr@@ as lo consi@@ guen con esta tri@@ an@@ gul@@ ación@@ : 6@@ 4@@ ...
# con esta liber@@ tad, sur@@ gió un nuevo tipo de expres@@ ión liter@@ aria.
# en el fin del perio@@ do inici@@ al, an@@ na bi@@ j@@ ns (@@ c.
# Estos ec@@ ms (@@ experim@@ ento conta@@ in@@ er mod@@ ul@@ as@@ ) est@@ and@@ ari@@ z@@ ados pueden con@@ tener experim@@ entos científi@@ cos.
# un acuerdo entre las cinco familias im@@ pidió la ad@@ ición de más edifici@@ os en el pueblo.
# Jack@@ son afir@@ ma que estos document@@ os eran los planes de los oficiales captur@@ ados de la bri@@ gada (@@ reg@@ lad@@ o@@ )@@ .
# varios experiment@@ os, tanto en el espacio y en la tierra, se llevan a cabo para evalu@@ ar el gr@@ ado exac@@ to de peligro.
# dan@@ i d@@ ani@@ els n@@ am@@ ed eleg@@ ante an@@ gel '@@ gir@@ l of the mon@@ th@@ '.
# En el momento de la edi@@ ción del 14@@ 9@@ 9 del regi@@ miento de la cosa pública.
# los ali@@ ados consider@@ an como probable una capi@@ tu@@ l@@ ación sovi@@ éti@@ ca.
# Sin embargo, nu@@ red@@ din se neg@@ ó a creer que los britá@@ nicos tom@@ arían este riesgo.
# a continu@@ ación se present@@ ó un informe final al consejo de seguridad y se hizo una declaración sobre la continua ayuda con la unidad de patrulla de fronter@@ as.
# así como la regla 3@@ 4 continu@@ ó exten@@ di@@ éndose por la intern@@ et, los medi@@ os de comunic@@ ación tradi@@ cion@@ ales empez@@ aron a informar sobre ella.
# hy@@ m@@ ne (@@ cre@@ ación a través de hu@@ esos.
# Estos matrimoni@@ os pueden ser pol@@ í@@ gam@@ os@@ ; en 20@@ 10 se entrevist@@ aron a una mujer que había tomado cinco espos@@ as.
# un hecho similar ocurrió en 11@@ 14 durante la aus@@ encia de los ob@@ is@@ pos a estr@@ as@@ bur@@ go.
# el v@@ ati@@ can@@ o confirm@@ ó que el títu@@ lo sería l@@ au@@ d@@ ato si@@ ' el 10 de jun@@ io.
# a los 12 años, k@@ im estaba familiari@@ z@@ ado con el negocio de los medi@@ os.
# será capaz de exam@@ inar el cielo más de diez mil veces más rápido que nunca antes.
# primero trabaj@@ ó para la revista americ@@ ana de arte the cr@@ ay@@ on.
# Entonces, la gu@@ y@@ ana ven@@ ez@@ ol@@ ana constitu@@ y@@ e, al contr@@ ario que los lan@@ os, una superfici@@ e de or@@ es@@ ión.
# casi la mitad entr@@ aron de manera ileg@@ al.
# 16 está en blan@@ co, y los ff.
# Al día siguiente por la mañana en la casa, be@@ atr@@ ice y yo discu@@ ten cómo tiene que ser una mujer segura de sí misma.
# en la capi@@ tal, una multi@@ tud se reunió el 16 de mar@@ zo.
# Jen@@ ni@@ fer se despier@@ ta en su casa de 20@@ 15 y se escon@@ de de la familia m@@ c@@ fl@@ y.
# los clu@@ bs de lec@@ tura y cafeter@@ ías permiti@@ eron a muchos ar@@ tes@@ anos y empres@@ arios ur@@ ban@@ os discutir las últimas ideas de re@@ forma.
# los otros 17 miembr@@ os, todos ellos tur@@ cos y ár@@ ab@@ es, bo@@ i@@ co@@ te@@ aron la vo@@ tación.
# aunque gran parte del libro tiene un ton@@ o de admir@@ ación para el pueblo alem@@ án, expres@@ ó una des@@ aprob@@ ación extre@@ ma por esta trad@@ ici@@ ón.
# Esta fue la última vez que ninguna película tuvo más de cuatro nom@@ in@@ aciones.
# En 198@@ 5, una película llamada pu@@ m@@ pin@@ g ir@@ on i@@ i@@ : la mujer fue liber@@ ada.
# otros miembr@@ os: s@@ hor@@ t bu@@ ll@@ ; amos b@@ ad hear@@ t bu@@ ll@@ .
# w@@ est@@ mor@@ el@@ and todavía era más en@@ fá@@ tico en sus afir@@ m@@ aciones.
# Esto demostr@@ ó que estoy destin@@ ado a ver los manuscri@@ tos del maestro z@@ h@@ u.
# El número de ofic@@ inas de la ent@@ idad llegó las 3@@ 50 en 200@@ 3.
# los edifici@@ os que al@@ ber@@ gan la colec@@ ción de ob@@ ras de pic@@ as@@ o tienen también su propia historia.
# por el final de la guerra, el 80@@ % de todos los pilot@@ os militar@@ es de los esta@@ dos un@@ idos habían recibido su vuelo inici@@ al de entrenamiento en pi@@ per cub@@ os.
# si el problema es abs@@ trac@@ to, prueba a exam@@ inar un ej@@ emp@@ lo concre@@ to.
# Pero ev@@ entu@@ almente también se le permi@@ tió partici@@ par en el con@@ clav@@ e.
# cualquier año que tiene 5@@ 3 juev@@ es tiene 5@@ 3 seman@@ as@@ ; esta semana extra puede ser consider@@ ada como inter@@ cal@@ ada.
# El comi@@ té central se ex@@ p@@ and@@ ía a 18@@ 3 miembr@@ os, con congr@@ esos de partido cada cinco años.
# Además, en este momento, la religi@@ ón ten@@ día a tener una relación ínti@@ ma con la po@@ es@@ ía.
# Realmente ech@@ aré de menos nuestras convers@@ aciones.
# Incluso ahora, un gran por@@ centa@@ je de la pobl@@ ación de 5@@ 5@@ .000 habit@@ antes todavía busc@@ an trabajo en esta industri@@ a.
# evel@@ yn vivi@@ ó con una familia jud@@ ía mientras estudi@@ aba en eur@@ op@@ a.
# en poner@@ lo@@ d juntos, entonces es como leer 40@@ ,@@ 22 i@@ u@@ ans.
# Fue también trans@@ crip@@ tor de las fun@@ dam@@ ental ur@@ der@@ s.
# Sus traduc@@ ciones son consider@@ ados clási@@ cos en Ru@@ sia.
# no está claro del todo como ke@@ ta@@ k@@ ar llegó a estos resul@@ tad@@ os, y su segundo plane@@ ta, vis@@ h@@ nu@@ , nunca se localiz@@ ó.
# el apoyo inter@@ no de Q@@ az@@ i mu@@ ham@@ ma@@ d finalmente de@@ cl@@ in@@ aba, especialmente entre las trib@@ us k@@ ur@@ des que le habían apoy@@ ado inici@@ almente.
# No solo eso, sino que gun@@ o cuestion@@ ó la leg@@ i@@ ti@@ mi@@ dad de sh@@ un como gobern@@ ante debido a su mod@@ esto lin@@ aje.
# Por otro lado el campo de m@@ all@@ ni@@ tz fue el peor.
# la organiz@@ ación y administr@@ ación del c@@ c@@ c fue un nuevo experim@@ ento en oper@@ aciones para una agencia del gobierno feder@@ al.
# en esa misma noche, cinco compañ@@ ías bri@@ t@@ án@@ ic@@ as intent@@ aron otro as@@ alto en la col@@ ina.
# ni los liber@@ ales ni los nacion@@ alis@@ tas ca@@ tal@@ an@@ es, ni re@@ publican@@ os, ni soci@@ alis@@ tas, ni an@@ arqui@@ s@@ tas.
# los in@@ migr@@ antes ne@@ er@@ lan@@ des@@ es también ex@@ portar@@ on la lengua ne@@ er@@ lan@@ desa.
# otra carta del mismo año inform@@ aba de que re@@ br@@ ía cier@@ tos privileg@@ ios por un servicio militar desconoci@@ do.
# en esta reg@@ ión se han identific@@ ado diez cast@@ ella y un campamento de leg@@ ion@@ arios.
# fue el au@@ tor del tratado militar de re militar@@ i (@@ 14@@ 7@@ 2@@ )@@ .
# Su defensa apar@@ ente de las trabaj@@ adoras del sexo solo está motiv@@ ada por sus interes@@ es empres@@ ari@@ ales, según e. vi@@ lla cam@@ a@@ arma.
# la estrateg@@ ia militar cu@@ ban@@ a al sur de agu@@ ja en 198@@ 8 llevó ur@@ gencia a las negoci@@ aciones.
# un sig@@ lo y medio más tarde, el 11 de sep@@ tiem@@ bre de 1.@@ 6@@ 8@@ 8, fue captur@@ ada por la re@@ pública de ven@@ e@@ cia.
# e. de@@ w@@ dne@@ y haría una apar@@ ición en el gran nor@@ oeste a fuerte wal@@ s@@ h ese verano.
# Sin embargo, la dónde ama que el 13@@ ,@@ 7@@ % de las mujeres de u@@ z@@ be@@ k@@ ist@@ án que quieren im@@ pedir o retras@@ ar su próximo embaraz@@ o no pueden hacerlo debido al acceso limi@@ tado a los anti@@ concep@@ tiv@@ os.

# %% [markdown]
# #Backtranslation: translate ES –> EN

# %%
# Load model
model_name = 'Helsinki-NLP/opus-mt-es-en'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/312M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/826k [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 28.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses) (4.65.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=d9b7b60117e7440d8af31dfa1f4dbce2973e1b153e59596a378c59a7431481ef
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53

# %%
src_text = open('/content/drive/MyDrive/MT2/ca-en/train.bcktr.es', 'r').readlines()
tgt_file = open('/content/drive/MyDrive/MT2/ca-en/train.bcktr.en', 'w')
for line in src_text:
  input = tokenizer(line, return_tensors="pt", padding=True)
  translated = model.generate(**input)
  tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
  tgt_file.write(tgt_text[0] + '\n')
tgt_file.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
'''translated = model.generate(**tokenizer(src_text, return_tensors="pt", padding=True))
tgt_text = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
with open('/content/drive/MyDrive/MT/ca-en/train.bcktr.en', 'w') as tgt_file:
  for text in tgt_text:
    tgt_file.write(text + '\n')
tgt_file.close()'''

# %% [markdown]
# ## Apply BPE model

# %%
# apply BPE model to ca-en training data
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/train.ca-en.en > $data_path/train.ca-en.bpe.en
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/train.ca-en.ca > $data_path/train.ca-en.bpe.ca

# %%
# apply BPE model to ca-es train data
# !subword-nmt apply-bpe -c '/content/esbpe.codes' < $data_path/train.ca-es.es > $data_path/train.ca-es.bpe.es
# !subword-nmt apply-bpe -c '/content/esbpe.codes' < $data_path/train.ca-es.ca > $data_path/train.ca-es.bpe.ca

# %%
# apply BPE model to ca-en validation data
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/dev.ca-en.en > $data_path/dev.ca-en.bpe.en
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/dev.ca-en.ca > $data_path/dev.ca-en.bpe.ca

# %%
# apply BPE model to ca-en test data
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/test.ca-en.en > $data_path/test.ca-en.bpe.en
# !subword-nmt apply-bpe -c '/content/bpe.codes' < $data_path/test.ca-en.ca > $data_path/test.ca-en.bpe.ca

# %%
# apply BPE model to backtranslated en data
# !subword-nmt apply-bpe -c '/content/bpe.codes' < '/content/joeynmt/data/enca/train.bcktr.en' > train.bcktr.bpe.en

# %%
# Combine the partial corpora to create final resources
# !cat $data_path/train.ca-en.bpe.en $data_path/train.ca-es.bpe.es $data_path/train.bcktr.bpe.es $data_path/train.bcktr.bpe.en > $data_path/train.bpe.en
# !cat $data_path/train.ca-en.bpe.ca $data_path/train.ca-es.bpe.ca $data_path/split.train.mono.bpe.ca $data_path/split.train.mono.bpe.ca > $data_path/train.bpe.ca

# Create that vocab using build_vocab
! sudo chmod 777 joeynmt/scripts/build_vocab.py
! joeynmt/scripts/build_vocab.py $data_path/train.bpe.en $data_path/train.bpe.ca --output_path $data_path/vocab.txt

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
#
#
#
# ---
